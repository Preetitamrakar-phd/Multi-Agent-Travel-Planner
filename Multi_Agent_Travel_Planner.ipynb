# %% [markdown]
# # **Travel Planning Multi-Agent system**
#
# An intelligent system that coordinates multiple specialized agents to search flights, hotels, plan itineraries, and provide personalized travel recommendations.

# %% [markdown]
# # **Step 1 - Start with the process to automate**
#
#
# *   Search hotels and flights based on user preferences
#
# *   Plan complete travel itineraries
#
#
# *   Answer travel-related questions with deep research
#
# *   Handle multiple queries in parallel
#
#
# *   Present unified, well-formatted travel recommendation

# %% [markdown]
# # **Step 2 & 3 - Map out your workflow as discrete steps & Identify what each steps need to do**
#
# *   **Search Agent:** Handles hotel and flight search based on user preferences.
#
# *  **Itinerary Planner Agent:** Utilizes search results and research to create detailed travel plans.

# %% [markdown]
# ## Install LangGraph

# %%
# !pip install -U -q langgraph langchain

# %% [markdown]
# ## Chat Model

# %%
# Install Required Libraries
# !pip install -U -q langchain-openai

# %%
# Import API Keys

import getpass
import os
from google.colab import userdata

try:
    api_key_from_secrets = userdata.get("OPENAI_API_KEY")
    os.environ["OPENAI_API_KEY"] = api_key_from_secrets
except Exception:
        os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
# Chat Model

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=os.getenv('OPENAI_CHAT_MODEL', 'gpt-4o-mini'),
    temperature=0.2,
    api_key=os.getenv('OPENAI_API_KEY')
)

# %% [markdown]
# ### Test Chat Model

# %%
test_msg = llm.invoke("What is Machine Learning? Explain with the help of an example.")

# %%
test_msg
# Out:
# AIMessage(content='Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machines learn from data and improve their performance over time through experience.\n\n### Key Concepts of Machine Learning:\n1. **Data**: The foundation of machine learning. It can be structured (like tables) or unstructured (like images or text).\n2. **Algorithms**: Mathematical models that process data to identify patterns or make predictions.\n3. **Training**: The process of feeding data into an algorithm so it can learn from it.\n4. **Testing**: Evaluating the model\'s performance on unseen data to ensure it generalizes well.\n5. **Prediction**: Using the trained model to make predictions on new data.\n\n### Example: Email Spam Detection\n\n**Problem Statement**: We want to classify emails as either "spam" or "not spam."\n\n**Step 1: Data Collection**\n- Gather a dataset of emails that have been labeled as "spam" or "not spam." This dataset might include various features like the subject line, sender\'s email address, and the content of the email.\n\n**Step 2: Feature Extraction**\n- Convert the emails into a format suitable for analysis. This might involve:\n  - Tokenizing the text (breaking it down into words).\n  - Removing stop words (common words like "the," "is," etc.).\n  - Creating a numerical representation (like a bag-of-words model or TF-IDF).\n\n**Step 3: Choosing an Algorithm**\n- Select a machine learning algorithm to use. Common choices for this task include:\n  - Naive Bayes\n  - Support Vector Machines (SVM)\n  - Decision Trees\n\n**Step 4: Training the Model**\n- Use the labeled dataset to train the chosen algorithm. The model learns to identify patterns that distinguish spam emails from non-spam emails based on the features extracted.\n\n**Step 5: Testing the Model**\n- Evaluate the model\'s performance using a separate test dataset (emails that the model hasn\'t seen before). Metrics like accuracy, precision, recall, and F1-score can be used to assess how well the model performs.\n\n**Step 6: Making Predictions**\n- Once the model is trained and tested, it can be deployed to classify new incoming emails. For example, if a new email arrives, the model analyzes its features and predicts whether it is spam or not.\n\n### Conclusion\nMachine learning enables systems to improve their performance on tasks like email classification by learning from data rather than relying on hard-coded rules. As more data becomes available and the model is refined, its accuracy and effectiveness in distinguishing between spam and non-spam emails can improve over time.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 566, 'prompt_tokens': 20, 'total_tokens': 586, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9afcdcbeed', 'id': 'chatcmpl-E8llwuUo6ciGR9aLX5efn4rga8v37', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fc787-6819-7b31-ad7a-3b91ac0bcf44-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 566, 'total_tokens': 586, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# Print in Readable Format
print(test_msg.text)
# Out:
# Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machines learn from data and improve their performance over time through experience.
#
# ### Key Concepts of Machine Learning:
# 1. **Data**: The foundation of machine learning. It can be structured (like tables) or unstructured (like images or text).
# 2. **Algorithms**: Mathematical models that process data to identify patterns or make predictions.
# 3. **Training**: The process of feeding data into an algorithm so it can learn from it.
# 4. **Testing**: Evaluating the model's performance on unseen data to ensure it generalizes well.
# 5. **Prediction**: Using the trained model to make predictions on new data.
#
# ### Example: Email Spam Detection
#
# **Problem Statement**: We want to classify emails as either "spam" or "not spam."
#
# **Step 1: Data Collection**
# - Gather a dataset of emails that have been labeled as "spam" or "not spam." This dataset might include various features like the subject line, sender's email address, and the content of the email.
#
# **Step 2: Feature Extraction**
# - Convert the emails into a format suitable for analysis. This might involve:
#   - Tokenizing the text (breaking it down into words).
#   - Removing stop words (common words like "the," "is," etc.).
#   - Creating a numerical representation (like a bag-of-words model or TF-IDF).
#
# **Step 3: Choosing an Algorithm**
# - Select a machine learning algorithm to use. Common choices for this task include:
#   - Naive Bayes
#   - Support Vector Machines (SVM)
#   - Decision Trees
#
# **Step 4: Training the Model**
# - Use the labeled dataset to train the chosen algorithm. The model learns to identify patterns that distinguish spam emails from non-spam emails based on the features extracted.
#
# **Step 5: Testing the Model**
# - Evaluate the model's performance using a separate test dataset (emails that the model hasn't seen before). Metrics like accuracy, precision, recall, and F1-score can be used to assess how well the model performs.
#
# **Step 6: Making Predictions**
# - Once the model is trained and tested, it can be deployed to classify new incoming emails. For example, if a new email arrives, the model analyzes its features and predicts whether it is spam or not.
#
# ### Conclusion
# Machine learning enables systems to improve their performance on tasks like email classification by learning from data rather than relying on hard-coded rules. As more data becomes available and the model is refined, its accuracy and effectiveness in distinguishing between spam and non-spam emails can improve over time.

# %% [markdown]
# ## Itinerary Agent

# %%
# Install Required Libraries

# !pip install -q deepagents tavily-python langchain-tavily

# %% [markdown]
# ### Web Search Tool

# %%
# Necessary Imports

from typing import Literal
from tavily import TavilyClient

# %%
from langchain.chat_models import init_chat_model
from deepagents import create_deep_agent

# %%
# Import API Keys

try:
    api_key_from_secrets = userdata.get("TAVILY_API_KEY")
    os.environ["TAVILY_API_KEY"] = api_key_from_secrets
except Exception:
        os.environ["TAVILY_API_KEY"] = getpass.getpass("Enter your Tavily API key: ")

# %%
# Create Internet Search vis TavilySearch

from langchain_tavily import TavilySearch

internet_search = TavilySearch(
    max_results=5,
    topic="general",
    # include_answer=False,
    # include_raw_content=False,
    include_images=True,
    include_image_descriptions=True,
    search_depth="advanced",
    # time_range="day",
    #include_domains=None,
    # exclude_domains=None
)

# %%
# Test internet_search
internet_search.invoke({"query": "Top Travel attractions in Vienna"})
# Out:
# {'query': 'Top Travel attractions in Vienna',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [{'url': 'https://epepa.eu/wp-content/uploads/2018/09/gloriette-schonbrunn-vienna.jpg',
#    'title': 'TOP 10 best things to do in Vienna, Austria | Epepa Travel Blog',
#    'description': 'A grand, neoclassical building with ornate statues and columns, likely part of a historic palace or museum in Vienna, with visitors strolling around on a sunny day.'},
#   {'url': 'https://media.timeout.com/images/106152216/image.jpg',
#    'title': '16 Best Attractions in Vienna for 2025',
#    'description': 'A horse-drawn carriage with a driver in traditional attire rides through a cobblestone street in front of a grand, baroque-style building with green domes and ornate architectural details in Vienna, Austria.'},
#   {'url': 'https://i.ytimg.com/vi/LVId4sgHlhM/maxresdefault.jpg',
#    'title': '10 Most Beautiful Places to Visit in Vienna Austria 🇦🇹 | Vienna Travel  Guide',
#    'description': 'A beautifully illuminated historical building in Vienna, featuring ornate architecture with a café at its entrance, and a horse-drawn carriage waiting nearby.'},
#   {'url': 'https://www.visitingvienna.com/wp-content/uploads/2025/04/michaelerplatz2025.jpg',
#    'title': 'Top 10 places to visit in Vienna',
#    'description': 'The Hofburg Palace in Vienna, Austria, features a grand baroque façade with elaborate sculptures, columns, and a central archway topped by a green dome under a clear blue sky.'},
#   {'url': 'https://viennapublictransport.com/wp-content/uploads/2024/08/wwwschoenbrunnat.jpg',
#    'title': 'Top Attractions and How to Reach Them by Public Transport - Vienna Public  Transport',
#    'description': 'A grand baroque palace with an expansive courtyard and elaborate gardens, set amidst lush greenery in Vienna.'}],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Tourist_attractions_in_Vienna',
#    'title': 'Tourist attractions in Vienna - Wikipedia',
#    'content': '## Effects of the global crisis\n\n[edit]\n\nIn 2003–2008 the Austrian tourism industry enjoyed a six-year streak of growth, with each year beating the previous record by an average 2.1%. Tourism generated 8.4% of Austrian gross domestic product (23.6 billion Euros) and provided 181 thousand jobs. The "top ten" of Vienna\'s tourist attractions in this period included the Schönbrunn Palace, Tiergarten Schönbrunn, the Albertina, the Wiener Riesenrad, the Hofburg Palace museums, the Belvedere "Belvedere (palace)"), the Kunsthistorisches and Naturhistorisches museums, the KunstHausWien and the Donauturm observation deck. [...] The tourist attractions of Vienna concentrate in three distinct areas. The largest cluster, centred on Schönbrunn Palace, attracted around five million visitors in 2009, down from six million in 2008. Museums and exhibitions of Hofburg Palace accounted for nearly two million visitors in 2008, with a significant decline in 2009. The third, and the newest, cluster of modern art museums in Museumsquartier attracted less than one million visitors. Nearby duo of Kunsthistorisches and Naturhistorisches museums, located halfway between Museumsquartier and Hofburg, also reported around one million visitors. The Landstraße district, which lies south-east of the old city, is home to art exhibitions at the Belvedere Palace "Belvedere (palace)") and the KunstHausWien. [...] | Rank 2009 | Place | Visitors | Location |\n ---  --- |\n| 2006 | 2007 | 2008 | 2009 |\n| 1 | Schönbrunn Palace Suburban palace of the Habsburgs | 2,507,000 | 2.590.000 | 2.581.000 | 2,467,000 | 48°11′5″N 16°18′44″E\ufeff / \ufeff48.18472°N 16.31222°E\ufeff / 48.18472; 16.31222 Schönbrunn Palace Park, Hietzing |\n| 2 | Tiergarten Schönbrunn World\'s oldest public zoo established in 1752 | 2,270,996 | 2,453,987 | 2,578,698 | 2,183,000 | 48°10′56″N 16°18′10″E\ufeff / \ufeff48.18222°N 16.30278°E\ufeff / 48.18222; 16.30278 Schönbrunn Palace Park, Hietzing |\n| 3 | Wiener Riesenrad The Ferris wheel in Prater | 620,000 | 620,000 | 660,000 | 640,000 | 48°13′00″N 16°23′45″E\ufeff / \ufeff48.21667°N 16.39583°E\ufeff / 48.21667; 16.39583 Prater park, Leopoldstadt |',
#    'score': 0.8995547,
#    'raw_content': None,
#    'images': [{'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Palacio_de_Sch%C3%B6nbrunn%2C_Viena%2C_Austria%2C_2020-02-02%2C_DD_28.jpg/1280px-Palacio_de_Sch%C3%B6nbrunn%2C_Viena%2C_Austria%2C_2020-02-02%2C_DD_28.jpg',
#      'description': None,
#      'description_source': 'og:image',
#      'score': 10},
#     {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Palacio_de_Sch%C3%B6nbrunn%2C_Viena%2C_Austria%2C_2020-02-02%2C_DD_28.jpg/250px-Palacio_de_Sch%C3%B6nbrunn%2C_Viena%2C_Austria%2C_2020-02-02%2C_DD_28.jpg',
#      'description': 'Schönbrunn Palace',
#      'description_source': 'alt',
#      'score': 2},
#     {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Wien_Rathaus_hochaufl%C3%B6send.jpg/250px-Wien_Rathaus_hochaufl%C3%B6send.jpg',
#      'description': 'Vienna City Hall, Rathaus',
#      'description_source': 'alt',
#      'score': 2},
#     {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Wien_-_Stephansdom_%281%29.JPG/250px-Wien_-_Stephansdom_%281%29.JPG',
#      'description': "St. Stephen's Cathedral",
#      'description_source': 'alt',
#      'score': 2},
#     {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/91/0101-0102_-_Wien_-_Naitonalbibliothek.jpg/250px-0101-0102_-_Wien_-_Naitonalbibliothek.jpg',
#      'description': 'Hofburg Palace',
#      'description_source': 'alt',
#      'score': 2},
#     {'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Wikivoyage-Logo-v3-icon.svg/20px-Wikivoyage-Logo-v3-icon.svg.png',
#      'description': 'Wikivoyage logo',
#      'description_source': 'alt',
#      'score': 2},
#     {'url': 'https://en.wikipedia.org/static/images/icons/enwiki-25.svg',
#      'description': None,
#      'description_source': None,
#      'score': 0}]},
#   {'url': 'https://thattravelista.com/vienna-austria-things-to-do',
#    'title': '13 Top Attractions and Things to Do in Vienna, Austria',
#    'content': 'Skip to content\n\nThat Travelista\n\nThat Travelista\n\nSchönbrunn Palace and Garden in Salzburg\n\nDETAILED ITINERARIES | EUROPE\n\n# 13 Top Attractions and Things to Do in Vienna, Austria\n\nByThat Travelista  \n\n2 Comments\n\nAs Austria’s capital and largest city, Vienna is a no-brainer to visit while in central Europe. The former seat of the powerful Habsburg Empire is today a destination synonymous with elegance and cultural charm. It’s home of the beloved Wienerschnitzel (Wien actually means Vienna in German), Viennese coffee, and world-renowned opera houses. Whether you’re visiting for the first time or making a repeat trip, you’ll find no shortage of things to do in Vienna.\n\n## Hofburg [...] ## Hofburg\n\nThe Hofburg is one of the largest palace complexes in the world and home to Austria’s former sovereigns. It started as a fortified medieval castle which grew and grew in size by each emperor, eventually becoming the seat of the powerful Habsburg Empire. Today, the Hoffburg’s many buildings are used by Austria’s current government, as well as museums that tourists can enter. This allows central Vienna’s largest buildings to have a cohesively beautiful look few other cities do.\n\nThe most popular museums in the Hofburg include the Sisi Museum (about the popular and mysterious Austrian queen), the Imperial Apartments, and the Silver Collection. Combined entry into all three will set you back €19.50, and you can purchase tickets online in advance at the official site. [...] ## Peterskirche\n\nPeterskirche is similar in style to Karlskirche. The church looks simple and clean from the exterior, but the inside is extremely intricate and colorfully decorated. Entry into the church is free. You can double-check opening times at the official site.\n\n## Prater Park & Giant Ferris Wheel\n\nPrater Amusement Park and its giant Ferris wheel have become a famous symbol for Vienna. The amusement park runs from mid-March to October, except for the ferris wheel, which is available for a spin year round. Each ride is between €6.50 and €14.50, so you can walk around the actual park itself for free.\n\n## So, What Do You Think?\n\nHave you been to Vienna? Is it on your list? Let me know in the comments below.\n\n### Save This List for Later on Pinterest\n\nThat Travelista',
#    'score': 0.8482825,
#    'raw_content': None,
#    'images': [{'url': 'https://thattravelista.com/wp-content/uploads/2020/08/Austria-Vienna-22.jpg',
#      'description': None,
#      'description_source': 'og:image',
#      'score': 10}]},
#   {'url': 'https://www.tripadvisor.com/Attractions-g190454-Activities-Vienna.html',
#    'title': 'THE 15 BEST Things to Do in Vienna (2026)',
#    'content': "Tripadvisor\n\n# Top 15 Things to Do in Vienna, Austria - Vienna Attractions\n\n# Top 30 Things to Do in Vienna\n\n## Explore popular experiences\n\n## Must-do experiences in Vienna\n\n### Vienna Classical Concert at St. Peter’s Church\n\n### Hallstatt Guided Day Trip from Vienna With Boat Ride Option\n\n### From Vienna, Lakes to Mountains, Hallstatt and Salzburg Tour\n\n### Vienna: Skip the Line Schönbrunn Palace and Gardens Guided Tour\n\n### Guided Walking Tour of Vienna City Center Highlights\n\n### Countryside Half Day Wine Tour near Vienna with meal & transfer\n\n### Entry Ticket Upper Belvedere, Klimt's Kiss & Permanent Collection\n\n### Hallstatt Small-Group Day Trip from Vienna\n\n### Bicycle tour - Vienna Complete\n\n### Best of Vienna : Historic Center Walking Tour\n\n## Top Attractions in Vienna [...] #### Public Transport Accessibility\n\nSome travelers said that Vienna's public transportation system is user-friendly for English speakers, easing navigation through the city. The public transport network is extensive, covering major parts of the city efficiently.\n\n#### Additional Travel Tips\n\nTravelers have called out the importance of using official resources like www.wienerlinien.at for comprehensive information on routes, schedules, and prices, ensuring a smoother travel experience within Vienna.\n\n#### Popular Attractions\n\nAccording to forum posts, some of Vienna's must-see attractions include Schönbrunn Palace, Hofburg Palace, and the Imperial Furniture Collection. Travelers have called out the historical importance and architectural beauty of these sites.\n\n#### Recommended Museums [...] ## Other Top Attractions around Vienna\n\n## Skip the lines at Schönbrunn\n\n## Walk through history and heritage\n\n## Classical Music\n\n## City Tours\n\n## Day Trips\n\n## Walking Tours\n\n## Family-friendly Shows\n\n## Full-day Tours\n\n## Half-day Tours\n\n## Private and Luxury\n\n### Really impressed!!!\n\n### Use Uber, never this taxi\n\n### Amazing artwork\n\n### Nice evening\n\n### Wonderful and simple!\n\n### Good cinema\n\n### A must for every amusement park lover!\n\n### Richly embellished\n\n### No more insider tips, plan a lot of Waiting time\n\n### Regret\n\n## Free things to do in Vienna\n\n## Outdoor activities in Vienna\n\n## Vienna travel tips\n\n#### Train and Subway Options",
#    'score': 0.83225065,
#    'raw_content': None,
#    'images': [{'url': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/2e/b4/5b/81/caption.jpg',
#      'description': None,
#      'description_source': 'og:image',
#      'score': 10},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/f6/4f/87/caption.jpg?w=1200&h=-1&s=1&cx=1920&cy=1080&chk=v1_9f19cdf59cf8b4cf0956',
#      'description': None,
#      'description_source': None,
#      'score': 3},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/0c/40/04/caption.jpg?w=1200&h=-1&s=1&cx=1920&cy=1080&chk=v1_300268e3dbcbf8fe6e3a',
#      'description': None,
#      'description_source': None,
#      'score': 3},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/26/c1/cc/caption.jpg?w=1200&h=-1&s=1&cx=1920&cy=1080&chk=v1_4ffab338edf9ee7e4c5d',
#      'description': None,
#      'description_source': None,
#      'score': 3},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/25/30/b0/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/da/1f/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/b8/93/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/f9/c6/3b/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/d7/32/12/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/b3/ad/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/81/0c/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/16/89/fa/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/c9/3d/46/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/98/3d/aa/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1c/2d/28/e4/wwwschoenbrunnat.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://static.tacdn.com/img2/tc/rebrand_2026/badges/2026/2026_Best_of_the_Best_Badge_Large.svg',
#      'description': "Travelers' Choice 2026 Winner",
#      'description_source': 'aria-label',
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/11/6b/48/6d/photo0jpg.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://static.tacdn.com/img2/tc/rebrand_2026/badges/2026/2026_TC_Badge_Large.svg',
#      'description': "Travelers' Choice 2026 Winner",
#      'description_source': 'aria-label',
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/13/80/54/93/oberes-belvedere-aussenansicht.jpg?w=500&h=400&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/16/4c/b1/20/als-palast-der-schonen.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/70/f4/d5/photo4jpg.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/ce/70/24/severin-wurnig.jpg?w=500&h=400&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/38/a2/40/prunksaal-der-osterreichischen.jpg?w=500&h=400&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/14/56/56/96/tiergarten-schonbrunn.jpg?w=500&h=400&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/c9/69/a5/wiener-prater.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/14/72/ab/d6/notturno-sul-terrazzo.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/ec/e8/93/caption.jpg?w=500&h=400&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/4f/83/96/state-opera-house.jpg?w=500&h=-1&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/17/b4/f5/melk-abbey.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/5a/31/2a/das-stift-klosterneuburg.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/34/01/8c/81/designer-outlet-parndorf.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/dd/64/80/familypark-neusiedlersee.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/05/13/08/0e/schlosspark-laxenburg.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/3e/6c/ea/cave.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/5e/c4/c8/beautiful-schloss-schoenbuehl.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/de/4b/c2/stiftsinnenhof-im-herbst.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/e7/25/4e/aerial-view-of-the-roman.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/4a/f8/b8/kurpark.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/19/e1/1a/e5/schloss-esterhazy.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/21/5c/17/26/schloss-hof-0011-c-schloss.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0e/39/63/06/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/80/b9/f9/relaxing-zone-in-the.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/23/69/4a/c3/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/90/14/e2/casino-baden.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/13/d9/68/1b/ruins-of-castle-up-there.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/12/5a/af/bb/benediktinerstift-gottweig.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/05/f8/37/98/nationalpark-donau-auen.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/10/21/74/0f/belediye-binasi.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/a9/21/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/bf/32/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/34/01/28/a3/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/ad/11/b8/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/27/92/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/f6/c4/f7/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/e8/7f/1c/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/9a/e8/e0/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/34/01/24/f8/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/a4/e3/47/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/a0/96/ce/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/ce/5b/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/0d/c3/b4/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/a6/5a/d2/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/29/d2/f9/0a/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/dd/12/8d/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/ae/4b/1d/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/b2/69/e5/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/1a/3f/c8/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/9c/81/ba/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/c9/d9/42/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/c3/21/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/72/85/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/9d/66/96/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/4b/8c/3a/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/a7/82/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/3d/70/a1/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/4b/b8/7d/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/f2/6f/25/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/bb/9d/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/35/11/8d/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/a5/92/0a/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/4d/10/88/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/f9/f9/fd/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/82/e5/1f/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/34/06/e8/79/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/82/b4/37/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/23/45/93/00/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/69/07/1b/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/9f/3a/97/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/05/6f/42/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/ae/96/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/bf/6d/57/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/97/b5/a0/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/fb/44/7f/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/54/0d/04/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/64/81/f4/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/8e/43/4b/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/33/81/1a/bc/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/c0/5d/a7/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/32/a9/d0/8e/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2},
#     {'url': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/31/50/02/66/caption.jpg?w=300&h=300&s=1',
#      'description': None,
#      'description_source': None,
#      'score': 2}]},
#   {'url': 'https://www.youtube.com/watch?v=LVId4sgHlhM',
#    'title': '10 Most Beautiful Places to Visit in Vienna Austria 🇦🇹 | Vienna Travel Guide',
#    'content': "# 10 Most Beautiful Places to Visit in Vienna Austria 🇦🇹 | Vienna Travel Guide\n## Lifestyle Hal\n200000 subscribers\n10338 likes\n\n### Description\n1123462 views\nPosted: 23 Feb 2023\n10 most beautiful places to visit in Vienna Austria. Some of the best places to visit in Vienna are right here in this Austria travel guide. If you ever wanted to know what to do in Vienna, some of the Amazing places in Vienna are attractions such as Schonbrunn Palace, Belvedere Palace, the Hofburg, the museumsquartier, Kunsthistorisches Museum, St Stephens Cathedral and many more attractions in Vienna. So if you have never been to Vienna before this quick travel guide will give you some ideas on Viennas Attractions in the city!. Have fun -  Toodle Pip !\n\nVIENNA CITY PASS  - [...] the emperor and Empress now the CC museum is an insight into the life of the often misunderstood Monarch and lastly you can see the silver collection but apart from that both the outside and inside of the palace are extremely impressive especially the graceful archways and the gorgeous courtyards [Music] foreign [Music] [Music] [Music] number three museums courtier now this area opened in 2001 but it's also a place to relax the site was once housed by the Habsburg Stables which was built in the early 18th century and it used to care for hundreds of animals so the good thing is now you don't get to smell a pile of the main attractions if you do visit this area are the Leopold Museum which is famous for the Sheila collection that could be something that's interesting you have the momoc [...] largely as it once was so let your feet take you along the pedestrianized roots and enjoy your surroundings just imagine a UNESCO world heritage that stretches across three square kilometers that is Vienna City Center [Music] in fact the old town just brims with history palaces classical music venues coffee houses and of course the beautiful buildings it's just a stunning City foreign now this was the former principal Imperial Palace of the Habsburg Dynasty and it's located in the center of Vienna built in the 13th century and expanded several times after it also served as the Imperial winter residence so when you do visit its main attractions are the Imperial Apartments where you can explore the private and official chambers of both the emperor and Empress now the CC museum is an insight",
#    'score': 0.81097376,
#    'raw_content': None,
#    'images': [{'url': 'https://i.ytimg.com/vi/LVId4sgHlhM/maxresdefault.jpg',
#      'description': None,
#      'description_source': 'og:image',
#      'score': 10}]},
#   {'url': 'https://danny-cph.com/vienna-things-to-do',
#    'title': 'My 12 Favorite Things to Do in Vienna, Austria (Based on Multiple Visits)',
#    'content': '#### My Top Vienna Activities:\n\n Ride on the world’s oldest operating ferris wheel (it’s quite pricey, but the views are worth it IMO)\n Spend an afternoon at Schönbrunn Palace (the gardens are free to wander around, but you have to pay for entry to the actual palace)\n Visit the Donauturm observation deck (you can get skip-the-line tickets in advance)\n\n#### Accommodation in Vienna:\n\nMy personal favorite hotel is Superbude Wien Prater, which I stayed at on a summer trip to the city. It’s a short train or Metro ride from the city’s main attractions and also right next to the famous Prater amusement park. The rooms were quirky, and the beds were comfortable. While I didn’t like the shower drainage, it was mostly a nice and affordable stay.',
#    'score': 0.7940821,
#    'raw_content': None,
#    'images': [{'url': 'https://danny-cph.com/wp-content/uploads/2023/05/Vienna-City-View-From-Donauturm.jpg',
#      'description': None,
#      'description_source': 'og:image',
#      'score': 10}]}],
#  'response_time': 4.62,
#  'request_id': '3f907757-3b32-454c-aa3a-97d2f40ca826'}

# %% [markdown]
# ### Deep Research Agent

# %%
# Define Model for Deep Research Agent
model = init_chat_model(model="gpt-4o-mini", model_provider="openai", temperature=0.2)

# %%
# Itinerary Agent (Deep Research) Prompt

from deepagents import create_deep_agent

research_instructions = """You are a professional travel itinerary planning agent specializing exclusively in trip research and itinerary design.

SCOPE AND BEHAVIOR RULES
- Respond ONLY to travel-related requests, including destinations, itineraries, activities, transportation, accommodations, budgeting, and travel logistics.
- If a request is unrelated to travel (e.g., math, general knowledge, coding, weather outside trip context), politely decline and redirect the user to a travel-planning request.
- Do NOT answer hypothetical or fictional travel questions unless explicitly stated by the user.

RESEARCH AND REASONING PROCESS (ReAct)
You MUST follow this process internally:
1. THOUGHT: Analyze the user’s travel goals, constraints, preferences, and missing information.
2. ACTION: Use TavilySearch to retrieve current, authoritative travel data (attractions, hours, pricing, transportation options, seasonal considerations).
3. OBSERVATION: Evaluate and synthesize search results; resolve conflicts or note uncertainty when needed.
4. RESPONSE: Produce a complete, user-ready itinerary.

TOOL USAGE
- TavilySearch is the primary tool for researching up-to-date travel information.
- Prefer official tourism boards, transportation providers, reputable travel guides, and recent reviews.
- Do not fabricate details if information is unavailable; explicitly state assumptions or gaps.

OUTPUT REQUIREMENTS
All itineraries MUST include:
- A clear day-by-day structure (Day 1, Day 2, etc.)
- Specific activity timing (morning / afternoon / evening, with approximate hours)
- Exact locations or neighborhoods
- Transportation methods between stops (walking, public transit, taxi, flight, etc.)
- Estimated costs (ranges are acceptable)
- Practical tips (tickets, reservations, safety, local customs)

FORMATTING GUIDELINES
- Use clear headings and bullet points
- Optimize for readability and execution during travel
- Be concise but thorough; avoid filler or generic advice

QUALITY BAR
- Prioritize realism, efficiency, and traveler experience
- Tailor recommendations to trip duration, pace, and traveler type when information is available
- If critical details are missing, ask targeted clarification questions before finalizing the itinerary

"""

# %%
# Itinerary Agent
itinerary_research_agent = create_deep_agent(
    model=model,
    system_prompt=research_instructions,
    tools=[internet_search],
)

# %%
# Test Itinerary Agent
result = itinerary_research_agent.invoke({"messages": [{"role": "user", "content": "Plan a 5 day travel iternerary for a food & hstorical sites lover during winter in Delhi"}]})

print(result)
# Out:
# {'messages': [HumanMessage(content='Plan a 5 day travel iternerary for a food & hstorical sites lover during winter in Delhi', additional_kwargs={}, response_metadata={}, id='e101a3de-50f4-4300-85e7-e670dbbdd7ac'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 3375, 'total_tokens': 3401, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_98fa25fd02', 'id': 'chatcmpl-E8lmQIW0vrHoHjZm6raQWSpmfTR3i', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc787-dfd5-7a83-834f-dacbb9fc3a2e-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Delhi food historical sites itinerary winter', 'search_depth': 'advanced'}, 'id': 'call_95DtIUfb6a9A558fov54WkWk', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3375, 'output_tokens': 26, 'total_tokens': 3401, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query": "Delhi food historical sites itinerary winter", "follow_up_questions": null, "answer": null, "images": [{"url": "https://www.thedelhitours.com/blog/wp-content/uploads/2026/01/Delhi-Winter-Experience.webp", "title": "Delhi Winter Experience: Weather, Food, Festivals & Travel Tips", "description": "A lively collage features iconic Delhi landmarks like India Gate and Qutub Minar, along with street vendors offering winter foods such as chai and traditional dishes, all set against a festive atmosphere with visitors, Indian flags, and decorative lights."}, {"url": "https://images.contentstack.io/v3/assets/blt06f605a34f1194ff/blt8bf83c7d1ab728df/67409fa81add866b10c30282/iStock-868408746-MOBILE_HEADER.jpg", "title": "New Delhi Winter Guide: 7 Things to See And Do", "description": "A variety of traditional Indian dishes including curry, rice, lentils, and naan, arranged on a dark surface, reflecting Delhi\'s winter food culture and historical culinary heritage."}, {"url": "https://i0.wp.com/passportsymphony.com/wp-content/uploads/2023/07/lodi-gardens.jpg.webp", "title": "18 Best Places To Visit In Delhi In Winter On Your Trip", "description": "A historic Mughal-era tomb surrounded by lush greenery and vibrant flowers, set against a bright blue sky with scattered clouds."}, {"url": "https://i0.wp.com/passportsymphony.com/wp-content/uploads/2023/10/things-to-do-in-delhi-in-winter-683x1024.jpg", "title": "18 Best Places To Visit In Delhi In Winter On Your Trip", "description": "The collage features illuminated historical monuments of Delhi, including the Lotus Temple, India Gate, Qutub Minar, and Humayun\'s Tomb, set against vibrant evening skies, with a mention of exploring winter travel activities and cuisine in Delhi."}, {"url": "https://dcvrfpttsu6tk.cloudfront.net/images/blog/images/2024-11-28-17-06-55-674855d72776b-13.jpg", "title": "Explore Old Delhi: Food, Heritage and Culture Tour", "description": "A variety of Indian street foods and drinks, including chaat served in edible bowls, accompanied by colorful chutneys and a bowl of yogurt, set against a background suggestive of Delhi\'s winter food experience."}], "results": [{"url": "https://www.ghumakkar.com/the-winter-old-delhi-food-tour", "title": "The winter Old-Delhi \\"food-tour\\" - Ghumakkar - Inspiring travel experiences.", "content": "I think there are lots of places to go…. u Can try Nand Lal ji ka Dhaba’s Grilled chicken and Korma simply awesome .there used to be some poori waala in lajpat rai market i dont know where it has disappeared.Theres one outlet of Cumsum at old delhi railway station and its briyaani worth going .Bedmi poori at jama mazjit are amaing ...

# %%
# Print the agent's response
print(result["messages"][-1].content)
# Out:
# Here's a 5-day itinerary for a food and historical sites lover visiting Delhi in winter. This itinerary combines culinary experiences with visits to significant historical landmarks.
#
# ### Day 1: Arrival and Old Delhi Exploration
# - **Morning:**
#   - **Arrival in Delhi**
#   - **Breakfast at Chachey Ke Dahi Balle** (8:00 AM - 9:00 AM)
#     - Location: Kamla Nagar
#     - Cost: ₹100-200
#   - **Explore Chandni Chowk** (9:30 AM - 12:00 PM)
#     - Visit **Jama Masjid** and **Paranthe Wali Gali** for deep-fried parathas.
#     - Cost: Free entry to Jama Masjid, Parathas around ₹50 each.
#
# - **Afternoon:**
#   - **Lunch at Kake di Hatti** (12:30 PM - 1:30 PM)
#     - Location: Chandni Chowk
#     - Must-try: Sarson da Saag and Makki di Roti.
#     - Cost: ₹300-500
#   - **Visit Red Fort** (2:00 PM - 4:00 PM)
#     - Entry Fee: ₹50
#     - Explore the Mughal architecture and history.
#
# - **Evening:**
#   - **Street Food Tour in Chandni Chowk** (4:30 PM - 7:00 PM)
#     - Try **Jalebi**, **Chole Bhature**, and **Daulat ki Chaat**.
#     - Cost: ₹200-300
#   - **Dinner at Karim's** (7:30 PM - 9:00 PM)
#     - Famous for Mughlai cuisine.
#     - Cost: ₹500-700
#
# ### Day 2: South Delhi and Cultural Sites
# - **Morning:**
#   - **Breakfast at All American Diner** (8:00 AM - 9:00 AM)
#     - Location: India Habitat Centre
#     - Cost: ₹400-600
#   - **Visit Humayun's Tomb** (9:30 AM - 11:00 AM)
#     - Entry Fee: ₹30
#     - Explore the UNESCO World Heritage Site.
#
# - **Afternoon:**
#   - **Lunch at Lodi the Garden Restaurant** (11:30 AM - 1:00 PM)
#     - Location: Near Lodi Gardens
#     - Cost: ₹800-1200
#   - **Stroll through Lodi Gardens** (1:30 PM - 3:00 PM)
#     - Free entry, enjoy the winter blooms and Mughal architecture.
#
# - **Evening:**
#   - **Visit Safdarjung's Tomb** (3:30 PM - 5:00 PM)
#     - Entry Fee: ₹20
#   - **Dinner at Khan Market** (6:00 PM - 8:00 PM)
#     - Options: Yum Yum Cha or Wok in the Clouds.
#     - Cost: ₹1000-1500
#
# ### Day 3: Culinary Delights and Markets
# - **Morning:**
#   - **Breakfast at a Local Chai Wala** (8:00 AM - 9:00 AM)
#     - Cost: ₹20-50
#   - **Visit Qutub Minar** (9:30 AM - 11:00 AM)
#     - Entry Fee: ₹30
#
# - **Afternoon:**
#   - **Lunch at a Local Dhaba** (11:30 AM - 1:00 PM)
#     - Try **Dhaniya da Dhaba** in Amar Colony.
#     - Cost: ₹300-500
#   - **Shopping at Dilli Haat** (1:30 PM - 4:00 PM)
#     - Explore handicrafts and local food stalls.
#
# - **Evening:**
#   - **Street Food Tour in Chittaranjan Park** (4:30 PM - 7:00 PM)
#     - Try **Puchka** and **Ghugni**.
#     - Cost: ₹200-300
#   - **Dinner at Bikanervala** (7:30 PM - 9:00 PM)
#     - Cost: ₹500-700
#
# ### Day 4: Cultural Immersion
# - **Morning:**
#   - **Breakfast at India Habitat Centre** (8:00 AM - 9:00 AM)
#   - **Visit the National Museum** (9:30 AM - 12:00 PM)
#     - Entry Fee: ₹20
#
# - **Afternoon:**
#   - **Lunch at the Museum Café** (12:30 PM - 1:30 PM)
#     - Cost: ₹300-500
#   - **Explore the Crafts Museum** (2:00 PM - 4:00 PM)
#     - Free entry, enjoy the exhibits.
#
# - **Evening:**
#   - **Dinner at a Local Restaurant in Connaught Place** (6:00 PM - 8:00 PM)
#     - Options: Saravana Bhavan for South Indian or Spice Route for Asian.
#     - Cost: ₹800-1200
#
# ### Day 5: Final Day and Departure
# - **Morning:**
#   - **Breakfast at a Local Café** (8:00 AM - 9:00 AM)
#   - **Visit India Gate and Raj Ghat** (9:30 AM - 11:00 AM)
#     - Free entry.
#
# - **Afternoon:**
#   - **Lunch at a Local Eatery** (11:30 AM - 1:00 PM)
#     - Try **Chole Bhature** at a local spot.
#     - Cost: ₹200-300
#   - **Last-minute Shopping at Connaught Place** (1:30 PM - 3:00 PM)
#
# - **Evening:**
#   - **Departure from Delhi**
#
# ### Practical Tips:
# - **Transportation:** Use the Delhi Metro for convenient travel between sites. Auto-rickshaws and taxis are also available.
# - **Weather:** Winter temperatures can be chilly; dress in layers.
# - **Reservations:** Consider making reservations for popular restaurants.
# - **Safety:** Keep an eye on your belongings, especially in crowded areas.
#
# This itinerary provides a balanced mix of food experiences and historical exploration, perfect for a winter visit to Delhi!

# %%
from IPython.display import Image, display

display(Image(itinerary_research_agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Flight & Hotel Search Agent

# %% [markdown]
# ### Flight & Hotel Search Tool

# %%
# API Key SetUp (Using Serp API for Flight & Hotel Serach)

try:
    api_key_from_secrets = userdata.get("SERPAPI_API_KEY")
    os.environ["SERPAPI_API_KEY"] = api_key_from_secrets
except Exception:
        os.environ["SERPAPI_API_KEY"] = getpass.getpass("Enter your Serp API key: ")

# %%
# Install required libraries

# !pip install -q google-search-results

# %%
# !pip install -q langchain-community

# %%
from langchain_community.utilities import SerpAPIWrapper
from serpapi import GoogleSearch
# Out:
# /tmp/ipykernel_40062/1097158722.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SerpAPIWrapper

# %%
import os
import json
from typing import Optional
from pydantic import BaseModel, Field
from serpapi import GoogleSearch
from langchain_core.tools import tool

# %%
# FLIGHT SEARCH TOOL
class FlightSearchInput(BaseModel):
    """Input schema for flight search."""

    departure_airport: str = Field(..., description="Departure airport code (e.g., 'JFK')")
    arrival_airport: str = Field(..., description="Arrival airport code (e.g., 'LAX')")
    outbound_date: str = Field(..., description="Departure date (YYYY-MM-DD)")
    return_date: Optional[str] = Field(None, description="Return date (YYYY-MM-DD)")
    adults: int = Field(1, description="Number of adults")
    children: int = Field(0, description="Number of children")
    stops: Optional[int] = Field(None, description="0=Any, 1=Nonstop, 2=1 stop or fewer")


@tool(args_schema=FlightSearchInput)
def search_flights(
    departure_airport: str,
    arrival_airport: str,
    outbound_date: str,
    return_date: Optional[str] = None,
    adults: int = 1,
    children: int = 0,
    stops: Optional[int] = None
) -> str:
    """Search for flights between airports."""

    params = {
        'api_key': os.environ.get('SERPAPI_API_KEY'),
        'engine': 'google_flights',
        'departure_id': departure_airport.upper(),
        'arrival_id': arrival_airport.upper(),
        'outbound_date': outbound_date,
        'adults': adults,
        'children': children,
        'currency': 'USD',
        'type': 1 if return_date else 2
    }

    if return_date:
        params['return_date'] = return_date
    if stops is not None:
        params['stops'] = stops

    try:
        results = GoogleSearch(params).get_dict()
        flights = results.get('best_flights', []) + results.get('other_flights', [])

        if not flights:
            return json.dumps({"message": "No flights found"})

        output = []
        for f in flights[:10]:
            output.append({
                "price": f.get("price"),
                "duration_mins": f.get("total_duration"),
                "airline_logo": f.get("airline_logo"),
                "legs": [{
                    "airline": leg.get("airline"),
                    "flight_number": leg.get("flight_number"),
                    "departure": f"{leg.get('departure_airport', {}).get('id')} {leg.get('departure_airport', {}).get('time')}",
                    "arrival": f"{leg.get('arrival_airport', {}).get('id')} {leg.get('arrival_airport', {}).get('time')}",
                    "airline_logo": leg.get("airline_logo")
                } for leg in f.get("flights", [])]
            })

        return json.dumps(output, indent=2)

    except Exception as e:
        return json.dumps({"error": str(e)})

# %%
# HOTEL SEARCH TOOL
class HotelSearchInput(BaseModel):
    """Input schema for hotel search."""

    location: str = Field(..., description="Location (e.g., 'New York', 'Paris')")
    check_in_date: str = Field(..., description="Check-in date (YYYY-MM-DD)")
    check_out_date: str = Field(..., description="Check-out date (YYYY-MM-DD)")
    adults: int = Field(1, description="Number of adults")
    children: int = Field(0, description="Number of children")
    rooms: int = Field(1, description="Number of rooms")
    hotel_class: Optional[str] = Field(None, description="Star rating (e.g., '3,4,5')")
    sort_by: int = Field(8, description="3=Price, 8=Rating, 13=Reviews")


@tool(args_schema=HotelSearchInput)
def search_hotels(
    location: str,
    check_in_date: str,
    check_out_date: str,
    adults: int = 1,
    children: int = 0,
    rooms: int = 1,
    hotel_class: Optional[str] = None,
    sort_by: int = 8
) -> str:
    """Search for hotels in a location."""

    params = {
        'api_key': os.environ.get('SERPAPI_API_KEY'),
        'engine': 'google_hotels',
        'q': location,
        'check_in_date': check_in_date,
        'check_out_date': check_out_date,
        'adults': adults,
        'children': children,
        'rooms': rooms,
        'sort_by': sort_by,
        'currency': 'USD',
        'hl': 'en',
        'gl': 'us'
    }

    if hotel_class:
        params['hotel_class'] = hotel_class

    try:
        results = GoogleSearch(params).get_dict()
        properties = results.get('properties', [])

        if not properties:
            return json.dumps({"message": "No hotels found"})

        output = []
        for h in properties[:5]:
            output.append({
                "name": h.get("name"),
                "price": h.get("rate_per_night", {}).get("lowest"),
                "rating": h.get("overall_rating"),
                "reviews": h.get("reviews"),
                "stars": h.get("hotel_class"),
                "thumbnail": h.get("images", [{}])[0].get("thumbnail") if h.get("images") else None
            })

        return json.dumps(output, indent=2)

    except Exception as e:
        return json.dumps({"error": str(e)})

# %%
search_tools = [search_flights, search_hotels]

# %% [markdown]
# ### Flight & Hotel Search Prompt

# %%
# flightHotelSearch Agent Prompt

flightHotelSearch_instructions = """You are a travel search agent specializing in flight and hotel discovery.
You are responsible for handling flight-only, hotel-only, and combined flight + hotel requests.

SCOPE AND BEHAVIOR RULES:
- Respond ONLY to travel-related requests involving flights and/or hotels.
- Politely decline and redirect if the request is unrelated to travel.
- You MUST use the appropriate tool(s) to retrieve current data.
- Do NOT fabricate availability, schedules, ratings, or prices.

AVAILABLE TOOLS:
You have exactly two tools:
- search_flights: Use to search for flights with structured flight inputs.
- search_hotels: Use to search for hotels with structured hotel inputs.

TOOL SELECTION RULES:
- Flight-only request → use search_flights
- Hotel-only request → use search_hotels
- Combined request → use BOTH tools
- Never call a tool if required inputs are missing.

REQUIRED INPUTS (ASK IF MISSING):

For search_flights:
- origin (city or airport code)
- destination (city or airport code) - this is optional
- departure_date (YYYY-MM-DD)
- return_date (YYYY-MM-DD) for round trips (if applicable)
- passengers

For search_hotels:
- destination/location (city or neighborhood)
- check_in (YYYY-MM-DD)
- check_out (YYYY-MM-DD)
- guests
- rooms
- preferences (star rating, amenities, rating threshold)
- budget_per_night or total_budget (if specified)

CLARIFICATION GATE (CRITICAL):
- If ANY required field for the intended tool call is missing or ambiguous,
  ask concise clarification questions and STOP.
- Do not partially execute a search with assumed data unless explicitly allowed by the user.

PROCESS (MANDATORY):
1. Classify the request as flight-only, hotel-only, or combined.
2. Extract all constraints and preferences from the user message.
3. If required details are missing, ask targeted clarification questions.
4. Call the appropriate tool(s) with well-formed structured input.
5. Analyze the returned results for relevance, trade-offs, and value.
6. Present clear, actionable recommendations.

AIRPORT CODE NORMALIZATION (FLIGHTS):
- If the user provides a city name (not an airport code) for origin and/or destination, you MUST convert it to the most suitable airport code before calling search_flights.
- Prefer the primary international airport for that city (or the best-served airport for typical commercial routes).
- If the city has multiple major airports (e.g., New York, London, Tokyo), ask a concise clarification question OR use a city-level/multi-airport code only if search_flights explicitly supports it.
- If you cannot confidently determine the correct airport code from the city name, ask a clarification question and STOP (do not guess).

OUTPUT REQUIREMENTS:

For Flight Results:
- Organize by outbound and return (if applicable)
- Include airline, timing, duration, layovers, cabin class, and price
- Highlight best options (e.g., fastest, cheapest, best value)

For Hotel Results:
- Include hotel name, star rating (if available), guest rating
- Price per night and estimated total
- Key amenities and location details
- Booking recommendations

For Combined Requests:
- Provide bundled recommendations (e.g., Value / Balanced / Comfort)
- Show estimated total trip cost (flight + hotel)
- Explain trade-offs clearly

FORMATTING GUIDELINES:
- Use clear headings and bullet points
- Optimize for quick comparison and decision-making
- Be concise, factual, and analytical

Airport code reference (examples):
- Delhi: DEL
- London Heathrow: LHR
- New York: JFK / LGA / EWR
- etc.
"""

# %% [markdown]
# ### Test Flight & Hotel Search

# %%
# Test flightHotelSearch Agent
from langchain.agents import create_agent

search_agent = create_agent(
    model=llm,  # Default model
    tools=search_tools,
    system_prompt=flightHotelSearch_instructions
    # middleware=[dynamic_model_selection]
)

# %%
search_result = search_agent.invoke({"messages": [{"role": "user", "content": "Find me flight, returning on January 22, 2026 from New York to London on January 18, 2026 for 1 adults only"}]})

# Print the agent's response
print(search_result)
print(search_result["messages"][-1].content)
# Out:
# {'messages': [HumanMessage(content='Find me flight, returning on January 22, 2026 from New York to London on January 18, 2026 for 1 adults only', additional_kwargs={}, response_metadata={}, id='b04f68e7-4188-41d0-8574-c4eb59030edd'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1119, 'total_tokens': 1186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_98fa25fd02', 'id': 'chatcmpl-E8ln8hnlUcVcZ8uKZv4SJ4R76Uhp2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc788-8b7e-7961-8121-c2c47ba79c47-0', tool_calls=[{'name': 'search_flights', 'args': {'departure_airport': 'JFK', 'arrival_airport': 'LHR', 'outbound_date': '2026-01-18', 'return_date': '2026-01-22', 'adults': 1}, 'id': 'call_VvT6E72GaaWNRPV80lePl6iw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1119, 'output_tokens': 67, 'total_tokens': 1186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"message": "No flights found"}', name='search_flights', id='ba93c0a0-a1e3-44ac-8119-bdb1d6d6d83b', tool_call_id='call_VvT6E72GaaWNRPV80lePl6iw'), AIMessage(content="I couldn't find any flights from New York (JFK) to London (LHR) for the specified dates of January 18, 2026, to January 22, 2026. \n\nIf you have flexibility in your travel dates or would like to explore other options, please let me know!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 1187, 'total_tokens': 1250, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_98fa25fd02', 'id': 'chatcmpl-E8lnA8oBYm8SKcJ9eQSE3eiBgxrQT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fc788-9353-7200-a8d8-ca14eacd063c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1187, 'output_tokens': 63, 'total_tokens': 1250, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# I couldn't find any flights from New York (JFK) to London (LHR) for the specified dates of January 18, 2026, to January 22, 2026.
#
# If you have flexibility in your travel dates or would like to explore other options, please let me know!

# %%
search_result = search_agent.invoke({"messages": [{"role": "user", "content": "Find me hotels on January 22, 2026 in London for 1 adults only for 2 nights"}]})

# Print the agent's response
print(search_result)
print(search_result["messages"][-1].content)
# Out:
# {'messages': [HumanMessage(content='Find me hotels on January 22, 2026 in London for 1 adults only for 2 nights', additional_kwargs={}, response_metadata={}, id='57b73f6f-a1fd-4830-b37c-81b7098e192f'), AIMessage(content='Could you please provide the following details to proceed with the hotel search in London?\n\n1. Check-out date (January 24, 2026).\n2. Number of rooms needed.\n3. Any specific preferences (star rating, amenities, etc.)?\n4. Budget per night or total budget (if applicable).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 1110, 'total_tokens': 1174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_98fa25fd02', 'id': 'chatcmpl-E8lnCYj9b5BaG2jFhzCFlPXMBtGt2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fc788-999b-72c0-b4bb-04fcca384472-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1110, 'output_tokens': 64, 'total_tokens': 1174, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Could you please provide the following details to proceed with the hotel search in London?
#
# 1. Check-out date (January 24, 2026).
# 2. Number of rooms needed.
# 3. Any specific preferences (star rating, amenities, etc.)?
# 4. Budget per night or total budget (if applicable).

# %%
from IPython.display import Image, display

display(Image(search_agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Travel Scout (for General Queries)

# %% [markdown]
# ### Travel Scout Prompt

# %%
# Travel Scout Prompt

travel_scout_instructions = """You are a General Travel Scout specializing in high-level travel information and guidance.
Your role is to answer general travel questions that do NOT require detailed itinerary planning,
flight searches, or hotel booking.

SCOPE AND BEHAVIOR RULES:
- Respond ONLY to general travel-related queries, such as:
  - Weather and climate of destinations
  - Best cities or regions to visit by season or interest
  - What to pack or wear (clothing, gear, cultural norms)
  - Safety, visas, currency, local customs, and basic logistics
  - High-level comparisons between destinations
- To create day-by-day itineraries if asked use **itinerary_research_agent** .
- Do NOT search or recommend specific flights or hotels.
- Politely decline and redirect if the request is unrelated to travel.

--------------------------------------------------
TOOL SELECTION RULES (CRITICAL)
--------------------------------------------------

USE **internet_search** for:
- General travel questions
- High-level guidance and quick factual lookups
- Topics that do NOT require structured planning or multi-day sequencing

Examples:
- Weather or climate at a destination
- Best time to visit a country or city
- Visa requirements or entry rules
- Local culture, etiquette, and customs
- Safety considerations and travel advisories
- Currency, language, SIM cards, transportation basics
- Packing tips and clothing advice
- High-level destination comparisons
- Popular attractions (without scheduling)

DO NOT create day-by-day itineraries when using internet_search.

--------------------------------------------------

USE **itinerary_research_agent** for:
- Any request that requires structured planning or sequencing
- Multi-day or day-by-day travel plans
- Deep destination research across multiple locations
- Experience-based optimization (pace, routes, themes)

Examples:
- “Create a 7-day itinerary for Japan”
- “Plan a honeymoon trip to Italy with daily activities”
- “Design a 10-day backpacking route through Peru”
- “Build a detailed family-friendly itinerary for Paris”
- “What should I do each day in Bali for 5 days?”

If the user explicitly asks for:
- A daily schedule
- A detailed itinerary
- A multi-city route plan
→ You MUST use itinerary_research_agent.

PROCESS (MANDATORY):
1. Identify the intent and depth of the travel question.
2. Select the correct tool based on Tool Selection Rules.
3. Execute the tool.
4. Synthesize results into a clear, concise, traveler-friendly response.
5. State assumptions, seasonal variations, or uncertainty if applicable.


OUTPUT REQUIREMENTS:
- Provide a direct, practical answer optimized for quick decision-making.
- Avoid deep research, long narratives, or detailed schedules.
- Include actionable tips when helpful (e.g., “best months,” “what to avoid,” “what to pack”).

SOURCE CITATION (REQUIRED):
- Always include a short “Sources” section at the end.
- Cite 2–4 reputable sources used via TavilySearch.
- Do not include raw URLs in the body; list sources clearly and concisely.

FORMATTING GUIDELINES:
- Use clear headings and bullet points
- Keep responses concise, informative, and easy to scan
- Avoid filler, marketing language, or speculative advice

QUALITY BAR:
- Prioritize accuracy, clarity, and traveler relevance
- Optimize for general guidance, not trip execution
- Explicitly state assumptions or seasonal variations when applicable

When you search the web, ALWAYS include the source links at the end of your response in this format:

**Sources:**
- [Title](URL)
- [Title](URL)

This helps users verify information and explore further.
"""

# %% [markdown]
# ### itinerary_research_agent as a Tool (Sub Agent)

# %%
# Defining itinerary_research_agent as a Tool

@tool("itinerary_research_agent", description="plans travel itinerary")
def call_itinerary_research_agent(query: str):
    result = itinerary_research_agent.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].content

# %% [markdown]
# ### Test Travel Scout

# %%
travel_scout = create_agent(
    model=llm,
    system_prompt=travel_scout_instructions,
    tools=[internet_search, call_itinerary_research_agent]
)

# %%
travel_scout_result = travel_scout.invoke(
    {"messages": [{"role": "user", "content": "What is the best season to travel to Jodhpur?"}]}
)
print(travel_scout_result["messages"][-1].content)
# Out:
# ### Best Season to Travel to Jodhpur
#
# The ideal time to visit Jodhpur is during the **winter months**, specifically from **November to February**. Here's a breakdown of what to expect during this season:
#
# - **Weather**:
#   - Daytime temperatures range from **7°C to 25°C** (45°F to 77°F), making it comfortable for outdoor activities.
#   - Nights can be chilly, so packing light woolens is advisable.
#
# - **Activities**:
#   - This period is perfect for exploring Jodhpur's famous attractions like **Mehrangarh Fort**, **Umaid Bhawan Palace**, and the vibrant markets.
#   - The clear skies and pleasant weather enhance the experience of sightseeing and cultural events.
#
# - **Festivals**:
#   - Several local festivals, including the **Rajasthan International Folk Festival** and the **Marwar Festival**, occur during this time, adding to the cultural richness of your visit.
#
# ### Other Seasons
#
# - **Spring (March to April)**:
#   - Temperatures start to rise, ranging from **20°C to 38°C**. It's still manageable for sightseeing, but it can get warm.
#
# - **Summer (April to June)**:
#   - Extremely hot, with temperatures often exceeding **40°C** (104°F). This is generally not recommended for travel due to discomfort.
#
# - **Monsoon (July to September)**:
#   - While the rains can be refreshing, they can also lead to humidity and unpredictable weather, making travel less enjoyable.
#
# ### Summary
# For the best experience in Jodhpur, plan your visit between **November and February** when the weather is most favorable for exploration and enjoyment of local culture.
#
# **Sources:**
# - [Best Time to Visit Jodhpur - Season, Climate, and Temperature](https://www.bajajfinserv.in/best-season-to-visit-jodhpur)
# - [Best Time To Visit Jodhpur > Weather, Temperature & Season](https://www.holidify.com/places/jodhpur/best-time-to-visit.html)
# - [Best time to visit Jodhpur: A guide | Surpura Bagh](https://www.surpurabagh.com/blogs/best-time-to-visit-jodhpur-a-season-by-season-guide.html)

# %%
travel_scout_result = travel_scout.invoke(
    {"messages": [{"role": "user", "content": "Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city"}]}
)
print(travel_scout_result["messages"][-1].content)
# Out:
# Here's a detailed 2-day itinerary for Agra, tailored for a history and culture lover who also enjoys exploring local cuisine.
#
# ### Day 1: Iconic Landmarks and Mughal Cuisine
#
# **Morning:**
# - **6:00 AM - Visit the Taj Mahal**
#   - **Duration:** 2 hours
#   - **Details:** Arrive early to witness the sunrise over this iconic monument. Entry fee: INR 1300 (foreigners), INR 50 (Indians).
#   - **Tip:** Book tickets online in advance to skip the lines.
#
# - **8:30 AM - Breakfast at Joney's Place**
#   - **Duration:** 1 hour
#   - **Cuisine:** Enjoy a hearty breakfast featuring local favorites like parathas and chai.
#   - **Cost:** Approx. INR 200.
#
# **Midday:**
# - **10:00 AM - Agra Fort**
#   - **Duration:** 2 hours
#   - **Details:** Explore this UNESCO World Heritage Site, known for its stunning architecture and historical significance. Entry fee: INR 650 (foreigners), INR 50 (Indians).
#   - **Tip:** Hire a guide for a more enriching experience.
#
# - **12:30 PM - Lunch at Pinch of Spice**
#   - **Duration:** 1 hour
#   - **Cuisine:** Savor authentic Mughlai dishes such as biryani and kebabs.
#   - **Cost:** Approx. INR 700.
#
# **Afternoon:**
# - **2:00 PM - Visit Itimad-ud-Daulah (Baby Taj)**
#   - **Duration:** 1 hour
#   - **Details:** This beautiful mausoleum is known for its intricate marble inlay work. Entry fee: INR 300.
#
# - **3:30 PM - Explore Kinari Bazaar**
#   - **Duration:** 1.5 hours
#   - **Details:** Stroll through this vibrant market known for handicrafts, textiles, and souvenirs.
#
# **Evening:**
# - **5:30 PM - Mehtab Bagh**
#   - **Duration:** 1.5 hours
#   - **Details:** Enjoy a serene view of the Taj Mahal from across the Yamuna River, especially beautiful at sunset. Entry fee: INR 250.
#
# - **7:00 PM - Dinner at Esphahan (The Oberoi Amarvilas)**
#   - **Duration:** 2 hours
#   - **Cuisine:** Experience fine dining with views of the Taj Mahal. Try the Royal Thali.
#   - **Cost:** Approx. INR 2500+.
#
# ---
#
# ### Day 2: Cultural Exploration and Culinary Delights
#
# **Morning:**
# - **7:30 AM - Breakfast at Dasaprakash**
#   - **Duration:** 1 hour
#   - **Cuisine:** Enjoy South Indian vegetarian dishes like dosas and idlis.
#   - **Cost:** Approx. INR 200.
#
# - **9:00 AM - Fatehpur Sikri**
#   - **Duration:** 3 hours
#   - **Details:** Drive 40 km to explore this UNESCO World Heritage Site, known for its stunning Mughal architecture. Entry fee: INR 610 (foreigners), INR 40 (Indians).
#   - **Tip:** Hire a local guide to learn about its history.
#
# **Midday:**
# - **12:30 PM - Lunch at a Local Eatery in Fatehpur Sikri**
#   - **Duration:** 1 hour
#   - **Cuisine:** Try local flavors and traditional Indian cuisine.
#   - **Cost:** Approx. INR 300.
#
# **Afternoon:**
# - **2:00 PM - Return to Agra and Relax**
#   - **Duration:** 1 hour
#
# - **3:00 PM - Visit Akbar's Tomb**
#   - **Duration:** 1 hour
#   - **Details:** Explore this magnificent tomb set in beautiful gardens. Entry fee: INR 30.
#
# - **4:30 PM - Explore Sadar Bazaar**
#   - **Duration:** 1.5 hours
#   - **Details:** Shop for local handicrafts and enjoy the bustling atmosphere.
#
# **Evening:**
# - **6:30 PM - Dinner at Mama Chicken Mama Franky House**
#   - **Duration:** 1.5 hours
#   - **Cuisine:** Enjoy tandoori rolls and Mughlai dishes.
#   - **Cost:** Approx. INR 500.
#
# - **8:00 PM - Optional: Mughal Heritage Walk**
#   - **Duration:** 1 hour
#   - **Details:** Join a guided walk through the lesser-known parts of Agra to learn about local history and culture.
#
# ### Estimated Costs:
# - **Total for Meals:** Approx. INR 4000 (for two days)
# - **Entry Fees:** Approx. INR 3000 (for major attractions)
# - **Transportation:** Auto-rickshaws or taxis for local travel (approx. INR 1000 total).
#
# ### Practical Tips:
# - **Best Time to Visit:** October to March for pleasant weather.
# - **Local Cuisine to Try:** Bedai-Jalebi, Mughlai Biryani, Petha (a local sweet).
# - **Transportation:** Auto-rickshaws for short distances, taxis for longer trips.
#
# Enjoy your cultural and culinary adventure in Agra!

# %% [markdown]
# ### Streaming

# %%
# Stream events
query = "What is the best season to travel to Jodhpur?"
for chunk in travel_scout.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    print(chunk)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1954, 'total_tokens': 1977, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8lo5iVBtyyRryeEuCgmNFPAdSIFY', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-710d-7a42-89db-e7ab19ea3eb6-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'best season to travel to Jodhpur'}, 'id': 'call_uQZR8jL1wJD9J59eDvtSo26I', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1954, 'output_tokens': 23, 'total_tokens': 1977, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tools': {'messages': [ToolMessage(content='{"query": "best season to travel to Jodhpur", "follow_up_questions": null, "answer": null, "images": [{"url": "https://www.holidify.com/images/bgImages/JODHPUR.jpg", "title": "Best Time To Visit Jodhpur > Weather, Temperature & Season", "description": "An aerial view of the Mehrangarh Fort towering over the blue city of Jodhpur."}, {"url": "https://clubmahindra.gumlet.io/blog/media/section_images/know-the-b-193aa6a1e62677b.jpg?w=376&dpr=2.6", "title": "Best time to visit Jodhpur - Best Month to visit in Jodhpur - Club Mahindra", "description": "A panoramic view of Jodhpur with its characteristic blue houses, a fortress on a hill to the left, and the setting sun casting a warm glow over the city, suggesting the pleasant weather suitable for visiting during cooler seasons."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115544/jodhpur.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "The image shows a densely packed cityscape of blue-painted buildings, typical of Jodhpur, with a clear sky and some greenery in the foreground."}, {"url": "https://imgcdn.flamingotravels.co.in/Images/City/Best-time-to-visit-jodhpur.jpg", "title": "Best Time to Visit Jodhpur 2026 | Flamingo Travels", "description": "A large ancient fortress or palace with massive stone walls and multiple levels, perched atop a hill overlooking a densely populated city with white buildings and a river, under a clear sky in pleasant weather during October or March."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115558/amer-fort-1600x900.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "A majestic fort perched on a rocky hill with a camel carrying tourists walking along a stone path at sunset, exemplifying the best season to visit Jodhpur."}], "results": [{"url": "https://www.bajajfinserv.in/best-season-to-visit-jodhpur", "title": "Best Time to Visit Jodhpur - Season, Climate, and Temperature", "content": "### 3. Minimal to no documentation\\n\\nEnjoy a hassle-free process with little paperwork required, making the loan application seamless.\\n\\n### 4. Quick disbursal\\n\\nGet your funds disbursed quickly, ensuring your travel plans can proceed without delays.\\n\\nShow More Show Less \\n\\n## Conclusion\\n\\nThe best season to visit Jodhpur is during winter, ensuring a delightful travel experience. From majestic forts to desert adventures, every moment in this historic city is magical. With the support of Insta Personal Loan, managing expenses becomes easy. Enjoy Jodhpur’s charm without worrying about finances and create unforgettable memories.\\n\\nCheck your Insta Personal Loan offer.\\n\\nTerms and conditions apply.\\n\\n### Related links [...] ## Jodhpur weather: Best time to visit Jodhpur\\n\\nThe climate in Jodhpur is largely influenced by its desert location, leading to extreme temperatures. The best time to visit Jodhpur is during the winter season, from October to March. During this period, the weather remains pleasant, ideal for outdoor exploration and cultural experiences. Avoid visiting in summer, when temperatures can soar above 45°C. Monsoons, while refreshing, bring unpredictable rains. By understanding the seasons, you can decide the best time to travel Jodhpur for a comfortable and enjoyable stay.\\n\\nShow More Show Less \\n\\n## Spring in Jodhpur\\n\\nSpring, from March to April, is warm but not unbearably hot, making it suitable for sightseeing.\\n\\nMonth Temperature (°C)Weather\\nMarch 20-35 Warm\\nApril 25-38 Warm [...] Spring offers clear skies and fewer crowds, but an early start to your day helps beat the heat.\\n\\nShow More Show Less \\n\\n## Autumn in Jodhpur\\n\\nAutumn, from September to October, marks the transition from monsoon to winter with comfortable temperatures.\\n\\nMonth Temperature (°C)Weather\\nSeptember 24-35 Pleasant\\nOctobe ...
# {'model': {'messages': [AIMessage(content="### Best Season to Travel to Jodhpur\n\nThe ideal time to visit Jodhpur is during the **winter months**, specifically from **November to February**. Here’s a breakdown of what to expect during this season:\n\n- **Weather**: \n  - Temperatures range from **7°C to 25°C** (45°F to 77°F).\n  - The weather is cool and pleasant, making it perfect for outdoor activities and sightseeing.\n\n- **Activities**: \n  - This period is great for exploring Jodhpur's famous attractions like **Mehrangarh Fort**, **Umaid Bhawan Palace**, and the vibrant local markets.\n  - Many cultural festivals, such as the **Rajasthan International Folk Festival**, take place during these months, adding to the experience.\n\n- **Crowds and Costs**: \n  - This is the **peak tourist season**, so expect larger crowds and higher accommodation prices. It's advisable to book your stay in advance.\n\n### Other Seasons\n\n- **Spring (March to April)**: \n  - Temperatures start to rise, ranging from **20°C to 38°C**. It’s still manageable for sightseeing, but it can get warm.\n\n- **Summer (April to June)**: \n  - Extremely hot, with temperatures often exceeding **40°C** (104°F). Not recommended for outdoor activities.\n\n- **Monsoon (July to September)**: \n  - Moderate rainfall occurs, which can be refreshing but also unpredictable. Temperatures are still high, making it less ideal for travel.\n\n### Packing Tips\n- **Winter**: Light woolens for evenings and early mornings.\n- **Spring/Summer**: Breathable cotton clothing, sun protection, and hydration essentials.\n\n### Conclusion\nFor the best experience in Jodhpur, plan your visit between **November and February** when the weather is most favorable for exploration and enjoyment.\n\n**Sources:**\n- [Best Time to Visit Jodhpur - Season, Climate, and Temperature](https://www.bajajfinserv.in/best-season-to-visit-jodhpur)\n- [Best Time To Visit Jodhpur > Weather, Temperature & Season](https://www.holidify.com/places/jodhpur/best-time-to-visit.html)\n- [Best time to visit Jodhpur: A guide | Surpura Bagh](https://www.surpurabagh.com/blogs/best-time-to-visit-jodhpur-a-season-by-season-guide.html)", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 503, 'prompt_tokens': 8770, 'total_tokens': 9273, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 8704}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loCVsWoBG6k8hxWWPF3gBa3RmhX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fc789-75e0-7a43-8a20-276ef442ae9c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8770, 'output_tokens': 503, 'total_tokens': 9273, 'input_token_details': {'audio': 0, 'cache_read': 8704}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}

# %%
for event in travel_scout.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",):
      print(event)
      event["messages"][-1].pretty_print()
# Out:
# {'messages': [HumanMessage(content='What is the best season to travel to Jodhpur?', additional_kwargs={}, response_metadata={}, id='29b29aea-40a2-4153-9367-6f30ea3a4181')]}
# ================================ Human Message =================================
#
# What is the best season to travel to Jodhpur?
# {'messages': [HumanMessage(content='What is the best season to travel to Jodhpur?', additional_kwargs={}, response_metadata={}, id='29b29aea-40a2-4153-9367-6f30ea3a4181'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1954, 'total_tokens': 1977, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loINTbdgktEFBy56coqpbKh135K', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-a51c-7402-a7ff-22a8a198692a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'best season to travel to Jodhpur'}, 'id': 'call_1kDYEMuRtz07fZM8PoH7zKNy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1954, 'output_tokens': 23, 'total_tokens': 1977, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (call_1kDYEMuRtz07fZM8PoH7zKNy)
#  Call ID: call_1kDYEMuRtz07fZM8PoH7zKNy
#   Args:
#     query: best season to travel to Jodhpur
# {'messages': [HumanMessage(content='What is the best season to travel to Jodhpur?', additional_kwargs={}, response_metadata={}, id='29b29aea-40a2-4153-9367-6f30ea3a4181'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1954, 'total_tokens': 1977, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loINTbdgktEFBy56coqpbKh135K', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-a51c-7402-a7ff-22a8a198692a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'best season to travel to Jodhpur'}, 'id': 'call_1kDYEMuRtz07fZM8PoH7zKNy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1954, 'output_tokens': 23, 'total_tokens': 1977, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query": "best season to travel to Jodhpur", "follow_up_questions": null, "answer": null, "images": [{"url": "https://www.holidify.com/images/bgImages/JODHPUR.jpg", "title": "Best Time To Visit Jodhpur > Weather, Temperature & Season", "description": "An aerial view of the Mehrangarh Fort towering over the blue city of Jodhpur."}, {"url": "https://clubmahindra.gumlet.io/blog/media/section_images/know-the-b-193aa6a1e62677b.jpg?w=376&dpr=2.6", "title": "Best time to visit Jodhpur - Best Month to visit in Jodhpur - Club Mahindra", "description": "A panoramic view of Jodhpur with its characteristic blue houses, a fortress on a hill to the left, and the setting sun casting a warm glow over the city, suggesting the pleasant weather suitable for visiting during cooler seasons."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115544/jodhpur.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "The image shows a densely packed cityscape of blue-painted buildings, typical of Jodhpur, with a clear sky and some greenery in the foreground."}, {"url": "https://imgcdn.flamingotravels.co.in/Images/City/Best-time-to-visit-jodhpur.jpg", "title": "Best Time to Visit Jodhpur 2026 | Flamingo Travels", "description": "A large ancient fortress or palace with massive stone walls and multiple levels, perched atop a hill overlooking a densely populated city with white buildings and a river, under a clear sky in pleasant weather during October or March."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115558/amer-fort-1600x900.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "A majestic fort perched on a rocky hill with a camel carrying tourists walking along a stone path at sunset, exemplifying the best season to visit Jodhpur."}], "results": [{"url": "https://www.bajajfinserv.in/best-season-to-visit-jodhpur", "title": "Best Time to Visit Jodhpur - Season, Climate, and Temperature", "content": "### 3. Minimal to no documentation\\n\\nEnjoy a hassle-free process with little paperwork required, making the loan application seamless.\\n\\n### 4. Quick disbursal\\n\\nGet your funds disbursed quickly, ensuring your travel plans can proceed without delays.\\n\\nShow More Show Less \\n\\n## Conclusion\\n\\nThe best season to visit Jodhpur is during winter, ensuring a delightful travel experience. From majestic forts to desert adventures, every moment in this historic city is magical. With the support of Insta Personal Loan, managing expenses becomes easy. Enjoy Jodhpur’s charm without worrying about finances and create unforgettable memories.\\n\\nCheck your Insta Personal Loan offer.\ ...
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "best season to travel to Jodhpur", "follow_up_questions": null, "answer": null, "images": [{"url": "https://www.holidify.com/images/bgImages/JODHPUR.jpg", "title": "Best Time To Visit Jodhpur > Weather, Temperature & Season", "description": "An aerial view of the Mehrangarh Fort towering over the blue city of Jodhpur."}, {"url": "https://clubmahindra.gumlet.io/blog/media/section_images/know-the-b-193aa6a1e62677b.jpg?w=376&dpr=2.6", "title": "Best time to visit Jodhpur - Best Month to visit in Jodhpur - Club Mahindra", "description": "A panoramic view of Jodhpur with its characteristic blue houses, a fortress on a hill to the left, and the setting sun casting a warm glow over the city, suggesting the pleasant weather suitable for visiting during cooler seasons."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115544/jodhpur.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "The image shows a densely packed cityscape of blue-painted buildings, typical of Jodhpur, with a clear sky and some greenery in the foreground."}, {"url": "https://imgcdn.flamingotravels.co.in/Images/City/Best-time-to-visit-jodhpur.jpg", "title": "Best Time to Visit Jodhpur 2026 | Flamingo Travels", "description": "A large ancient fortress or palace with massive stone walls and multiple levels, perched atop a hill overlooking a densely populated city with white buildings and a river, under a clear sky in pleasant weather during October or March."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115558/amer-fort-1600x900.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "A majestic fort perched on a rocky hill with a camel carrying tourists walking along a stone path at sunset, exemplifying the best season to visit Jodhpur."}], "results": [{"url": "https://www.bajajfinserv.in/best-season-to-visit-jodhpur", "title": "Best Time to Visit Jodhpur - Season, Climate, and Temperature", "content": "### 3. Minimal to no documentation\n\nEnjoy a hassle-free process with little paperwork required, making the loan application seamless.\n\n### 4. Quick disbursal\n\nGet your funds disbursed quickly, ensuring your travel plans can proceed without delays.\n\nShow More Show Less \n\n## Conclusion\n\nThe best season to visit Jodhpur is during winter, ensuring a delightful travel experience. From majestic forts to desert adventures, every moment in this historic city is magical. With the support of Insta Personal Loan, managing expenses becomes easy. Enjoy Jodhpur’s charm without worrying about finances and create unforgettable memories.\n\nCheck your Insta Personal Loan offer.\n\nTerms and conditions apply.\n\n### Related links [...] ## Jodhpur weather: Best time to visit Jodhpur\n\nThe climate in Jodhpur is largely influenced by its desert location, leading to extreme temperatures. The best time to visit Jodhpur is during the winter season, from October to March. During this period, the weather remains pleasant, ideal for outdoor exploration and cultural experiences. Avoid visiting in summer, when temperatures can soar above 45°C. Monsoons, while refreshing, bring unpredictable rains. By understanding the seasons, you can decide the best time to travel Jodhpur for a comfortable and enjoyable stay.\n\nShow More Show Less \n\n## Spring in Jodhpur\n\nSpring, from March to April, is warm but not unbearably hot, making it suitable for sightseeing.\n\nMonth Temperature (°C)Weather\nMarch 20-35 Warm\nApril 25-38 Warm [...] Spring offers clear skies and fewer crowds, but an early start to your day helps beat the heat.\n\nShow More Show Less \n\n## Autumn in Jodhpur\n\nAutumn, from September to October, marks the transition from monsoon to winter with comfortable temperatures.\n\nMonth Temperature (°C)Weather\nSeptember 24-35 Pleasant\nOctober 20-30 Mild and dry\n\nAutumn is ideal for exploring historic sites like Mehrangarh  ...
# {'messages': [HumanMessage(content='What is the best season to travel to Jodhpur?', additional_kwargs={}, response_metadata={}, id='29b29aea-40a2-4153-9367-6f30ea3a4181'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1954, 'total_tokens': 1977, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loINTbdgktEFBy56coqpbKh135K', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-a51c-7402-a7ff-22a8a198692a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'best season to travel to Jodhpur'}, 'id': 'call_1kDYEMuRtz07fZM8PoH7zKNy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1954, 'output_tokens': 23, 'total_tokens': 1977, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query": "best season to travel to Jodhpur", "follow_up_questions": null, "answer": null, "images": [{"url": "https://www.holidify.com/images/bgImages/JODHPUR.jpg", "title": "Best Time To Visit Jodhpur > Weather, Temperature & Season", "description": "An aerial view of the Mehrangarh Fort towering over the blue city of Jodhpur."}, {"url": "https://clubmahindra.gumlet.io/blog/media/section_images/know-the-b-193aa6a1e62677b.jpg?w=376&dpr=2.6", "title": "Best time to visit Jodhpur - Best Month to visit in Jodhpur - Club Mahindra", "description": "A panoramic view of Jodhpur with its characteristic blue houses, a fortress on a hill to the left, and the setting sun casting a warm glow over the city, suggesting the pleasant weather suitable for visiting during cooler seasons."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115544/jodhpur.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "The image shows a densely packed cityscape of blue-painted buildings, typical of Jodhpur, with a clear sky and some greenery in the foreground."}, {"url": "https://imgcdn.flamingotravels.co.in/Images/City/Best-time-to-visit-jodhpur.jpg", "title": "Best Time to Visit Jodhpur 2026 | Flamingo Travels", "description": "A large ancient fortress or palace with massive stone walls and multiple levels, perched atop a hill overlooking a densely populated city with white buildings and a river, under a clear sky in pleasant weather during October or March."}, {"url": "https://images.travelandleisureasia.com/wp-content/uploads/sites/5/2024/04/15115558/amer-fort-1600x900.jpeg", "title": "These Are The Best Times To Visit Rajasthan For Fun", "description": "A majestic fort perched on a rocky hill with a camel carrying tourists walking along a stone path at sunset, exemplifying the best season to visit Jodhpur."}], "results": [{"url": "https://www.bajajfinserv.in/best-season-to-visit-jodhpur", "title": "Best Time to Visit Jodhpur - Season, Climate, and Temperature", "content": "### 3. Minimal to no documentation\\n\\nEnjoy a hassle-free process with little paperwork required, making the loan application seamless.\\n\\n### 4. Quick disbursal\\n\\nGet your funds disbursed quickly, ensuring your travel plans can proceed without delays.\\n\\nShow More Show Less \\n\\n## Conclusion\\n\\nThe best season to visit Jodhpur is during winter, ensuring a delightful travel experience. From majestic forts to desert adventures, every moment in this historic city is magical. With the support of Insta Personal Loan, managing expenses becomes easy. Enjoy Jodhpur’s charm without worrying about finances and create unforgettable memories.\\n\\nCheck your Insta Personal Loan offer.\ ...
# ================================== Ai Message ==================================
#
# ### Best Season to Travel to Jodhpur
#
# The ideal time to visit Jodhpur is during the **winter months**, from **November to February**. Here’s a breakdown of what to expect during this period:
#
# - **Weather**:
#   - **Temperatures**: Ranges from about **7°C to 25°C** (45°F to 77°F).
#   - **Conditions**: Pleasant and cool, perfect for outdoor activities and sightseeing.
#
# - **Activities**:
#   - This season is ideal for exploring Jodhpur's famous attractions like **Mehrangarh Fort**, **Umaid Bhawan Palace**, and the vibrant local markets.
#   - Cultural events such as the **Rajasthan International Folk Festival** and the **Marwar Festival** typically occur during this time, adding to the experience.
#
# ### Other Seasons
#
# - **Spring (March to April)**:
#   - Temperatures start to rise, ranging from **20°C to 38°C** (68°F to 100°F). It's still manageable for sightseeing but can get warm.
#
# - **Summer (April to June)**:
#   - Extremely hot, with temperatures often exceeding **40°C** (104°F). Not recommended for travel unless you can handle the heat.
#
# - **Monsoon (July to September)**:
#   - Humidity increases with occasional rain. While temperatures are lower, the weather can be unpredictable.
#
# ### Travel Tips
# - **Packing**: Bring light woolens for the winter evenings and breathable cottons for the warmer months.
# - **Booking**: If traveling in peak season (November to February), book accommodations in advance as they fill up quickly.
#
# ### Conclusion
# For a comfortable and enjoyable experience, plan your visit to Jodhpur between November and February when the weather is at its best.
#
# **Sources:**
# - [Best Time to Visit Jodhpur - Bajaj Finserv](https://www.bajajfinserv.in/best-season-to-visit-jodhpur)
# - [Best Time To Visit Jodhpur - Holidify](https://www.holidify.com/places/jodhpur/best-time-to-visit.html)
# - [Best time to visit Jodhpur: A guide | Surpura Bagh](https://www.surpurabagh.com/blogs/best-time-to-visit-jodhpur-a-season-by-season-guide.html)

# %%
query = "Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city"
for event in travel_scout.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",):
      print(event)
      event["messages"][-1].pretty_print()
# Out:
# {'messages': [HumanMessage(content='Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city', additional_kwargs={}, response_metadata={}, id='ef644f1a-4a0b-406e-a72b-c273459da0d8')]}
# ================================ Human Message =================================
#
# Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city
# {'messages': [HumanMessage(content='Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city', additional_kwargs={}, response_metadata={}, id='ef644f1a-4a0b-406e-a72b-c273459da0d8'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 1968, 'total_tokens': 2001, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loRz498qyZCR28Ike702U7ZpmS3', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-c560-7d41-a864-fa6d8e8ab37e-0', tool_calls=[{'name': 'itinerary_research_agent', 'args': {'query': '2 day itinerary for Agra travel for a history & culture lover, including special cuisine'}, 'id': 'call_0Mf9Q3ZKGIp3XdNIM6iTRakc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1968, 'output_tokens': 33, 'total_tokens': 2001, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ================================== Ai Message ==================================
# Tool Calls:
#   itinerary_research_agent (call_0Mf9Q3ZKGIp3XdNIM6iTRakc)
#  Call ID: call_0Mf9Q3ZKGIp3XdNIM6iTRakc
#   Args:
#     query: 2 day itinerary for Agra travel for a history & culture lover, including special cuisine
# {'messages': [HumanMessage(content='Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city', additional_kwargs={}, response_metadata={}, id='ef644f1a-4a0b-406e-a72b-c273459da0d8'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 1968, 'total_tokens': 2001, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loRz498qyZCR28Ike702U7ZpmS3', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-c560-7d41-a864-fa6d8e8ab37e-0', tool_calls=[{'name': 'itinerary_research_agent', 'args': {'query': '2 day itinerary for Agra travel for a history & culture lover, including special cuisine'}, 'id': 'call_0Mf9Q3ZKGIp3XdNIM6iTRakc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1968, 'output_tokens': 33, 'total_tokens': 2001, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Here's a detailed 2-day itinerary for Agra, tailored for a history and culture lover, including special cuisine experiences.\n\n### Day 1: Exploring Agra's Heritage\n\n#### Morning\n- **7:00 AM - Visit the Taj Mahal**\n  - **Duration:** 2 hours\n  - **Details:** Start your day early to witness the sunrise at the Taj Mahal, a UNESCO World Heritage Site and one of the Seven Wonders of the World.\n  - **Cost:** INR 1,300 (foreigners) / INR 50 (Indians)\n  \n- **9:00 AM - Breakfast at Joney’s Place**\n  - **Duration:** 1 hour\n  - **Details:** Enjoy a hearty breakfast at this popular local spot known for its delicious Indian breakfast options.\n  - **Cost:** INR 200\n\n#### Late Morning\n- **10:30 AM - Visit Agra Fort**\n  - **Duration:** 2 hours\n  - **Details:** Explore this massive red sandstone fort, another UNESCO World Heritage Site, featuring impressive gates and stunning views of the Taj Mahal.\n  - **Cost:** INR 650 (foreigners) / INR 50 (Indians)\n\n#### Afternoon\n- **1:00 PM - Lunch at Pinch of Spice**\n  - **Duration:** 1 hour\n  - **Details:** Savor authentic Mughlai cuisine, including kebabs and biryanis, at this well-reviewed restaurant.\n  - **Cost:** INR 700\n\n- **2:30 PM - Visit Itimad-ud-Daulah (Baby Taj)**\n  - **Duration:** 1.5 hours\n  - **Details:** Known for its intricate marble inlay work, this mausoleum is often referred to as the 'Baby Taj.'\n  - **Cost:** INR 300\n\n#### Evening\n- **4:00 PM - Stroll through Kinari Bazaar**\n  - **Duration:** 1.5 hours\n  - **Details:** Explore this vibrant market known for its handicrafts, marble souvenirs, and textiles.\n  - **Cost:** Free\n\n- **6:00 PM - Visit Mehtab Bagh**\n  - **Duration:** 1.5 hours\n  - **Details:** Relax in this garden complex across the Yamuna River, offering stunning sunset views of the Taj Mahal.\n  - **Cost:** INR 200\n\n- **7:30 PM - Dinner at Esphahan, Oberoi Amarvilas**\n  - **Duration:** 2 hours\n  - **Details:** Experience fine dining with views of the Taj Mahal, serving contemporary Indian cuisine.\n  - **Cost:** INR 2,500+\n\n### Day 2: Cultural Immersion and Culinary Delights\n\n#### Morning\n- **7:30 AM - Breakfast at the Hotel**\n  - **Duration:** 1 hour\n  - **Details:** Enjoy a leisurely breakfast at your hotel.\n\n- **8:30 AM - Excursion to Fatehpur Sikri**\n  - **Duration:** 3 hours\n  - **Details:** Drive to this UNESCO World Heritage Site, the former capital of Emperor Akbar, featuring impressive palaces and the grand Buland Darwaza.\n  - **Cost:** INR 610 (foreigners) / INR 50 (Indians)\n\n#### Afternoon\n- **12:00 PM - Return to Agra and Lunch at Dasaprakash**\n  ...
# ================================= Tool Message =================================
# Name: itinerary_research_agent
#
# Here's a detailed 2-day itinerary for Agra, tailored for a history and culture lover, including special cuisine experiences.
#
# ### Day 1: Exploring Agra's Heritage
#
# #### Morning
# - **7:00 AM - Visit the Taj Mahal**
#   - **Duration:** 2 hours
#   - **Details:** Start your day early to witness the sunrise at the Taj Mahal, a UNESCO World Heritage Site and one of the Seven Wonders of the World.
#   - **Cost:** INR 1,300 (foreigners) / INR 50 (Indians)
#
# - **9:00 AM - Breakfast at Joney’s Place**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy a hearty breakfast at this popular local spot known for its delicious Indian breakfast options.
#   - **Cost:** INR 200
#
# #### Late Morning
# - **10:30 AM - Visit Agra Fort**
#   - **Duration:** 2 hours
#   - **Details:** Explore this massive red sandstone fort, another UNESCO World Heritage Site, featuring impressive gates and stunning views of the Taj Mahal.
#   - **Cost:** INR 650 (foreigners) / INR 50 (Indians)
#
# #### Afternoon
# - **1:00 PM - Lunch at Pinch of Spice**
#   - **Duration:** 1 hour
#   - **Details:** Savor authentic Mughlai cuisine, including kebabs and biryanis, at this well-reviewed restaurant.
#   - **Cost:** INR 700
#
# - **2:30 PM - Visit Itimad-ud-Daulah (Baby Taj)**
#   - **Duration:** 1.5 hours
#   - **Details:** Known for its intricate marble inlay work, this mausoleum is often referred to as the 'Baby Taj.'
#   - **Cost:** INR 300
#
# #### Evening
# - **4:00 PM - Stroll through Kinari Bazaar**
#   - **Duration:** 1.5 hours
#   - **Details:** Explore this vibrant market known for its handicrafts, marble souvenirs, and textiles.
#   - **Cost:** Free
#
# - **6:00 PM - Visit Mehtab Bagh**
#   - **Duration:** 1.5 hours
#   - **Details:** Relax in this garden complex across the Yamuna River, offering stunning sunset views of the Taj Mahal.
#   - **Cost:** INR 200
#
# - **7:30 PM - Dinner at Esphahan, Oberoi Amarvilas**
#   - **Duration:** 2 hours
#   - **Details:** Experience fine dining with views of the Taj Mahal, serving contemporary Indian cuisine.
#   - **Cost:** INR 2,500+
#
# ### Day 2: Cultural Immersion and Culinary Delights
#
# #### Morning
# - **7:30 AM - Breakfast at the Hotel**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy a leisurely breakfast at your hotel.
#
# - **8:30 AM - Excursion to Fatehpur Sikri**
#   - **Duration:** 3 hours
#   - **Details:** Drive to this UNESCO World Heritage Site, the former capital of Emperor Akbar, featuring impressive palaces and the grand Buland Darwaza.
#   - **Cost:** INR 610 (foreigners) / INR 50 (Indians)
#
# #### Afternoon
# - **12:00 PM - Return to Agra and Lunch at Dasaprakash**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy delicious South Indian vegetarian cuisine, famous for dosas and thalis.
#   - **Cost:** INR 500
#
# - **1:30 PM - Visit Akbar's Tomb in Sikandra**
#   - **Duration:** 1.5 hours
#   - **Details:** Explore this architectural marvel set amidst beautiful gardens, reflecting the grandeur of the Mughal Empire.
#   - **Cost:** INR 100
#
# #### Evening
# - **3:00 PM - Relax at the Hotel**
#   - **Duration:** 1.5 hours
#   - **Details:** Take some time to rest and refresh before the evening activities.
#
# - **5:00 PM - Mughal Heritage Walk**
#   - **Duration:** 2 hours
#   - **Details:** Participate in a guided tour through the lesser-known parts of Agra, offering insights into local lifestyle and history.
#   - **Cost:** INR 1,000 (approx.)
#
# - **7:30 PM - Dinner at Peshawri, ITC Mughal**
#   - **Duration:** 2 hours
#   - **Details:** Dine on exquisite North-West Frontier cuisine in a luxurious setting, perfect for concluding your cultural journey.
#   - **Cost:** INR 2,000
#
# ### Practical Tips
# - **Transportation:** Auto-rickshaws are available for short distances; consider hiring a private car for longer trips.
# - **Best Time to Visit:** October to March for pleasant weather.
# - **Must-Try Food:** Bedai-Jalebi, Mughlai Biryani, Petha (a local sweet).
# - **Shopping:** Sadar Bazaar for handicrafts, Kinari Bazaar for marble souvenirs.
#
# Enjoy your enriching journey through Agra's history, culture, and cuisine!
# {'messages': [HumanMessage(content='Plan 2 day itinerary for Agra travel for a history & culture lover, also want to try special cusine to this city', additional_kwargs={}, response_metadata={}, id='ef644f1a-4a0b-406e-a72b-c273459da0d8'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 1968, 'total_tokens': 2001, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4cd46a3bc2', 'id': 'chatcmpl-E8loRz498qyZCR28Ike702U7ZpmS3', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fc789-c560-7d41-a864-fa6d8e8ab37e-0', tool_calls=[{'name': 'itinerary_research_agent', 'args': {'query': '2 day itinerary for Agra travel for a history & culture lover, including special cuisine'}, 'id': 'call_0Mf9Q3ZKGIp3XdNIM6iTRakc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1968, 'output_tokens': 33, 'total_tokens': 2001, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Here's a detailed 2-day itinerary for Agra, tailored for a history and culture lover, including special cuisine experiences.\n\n### Day 1: Exploring Agra's Heritage\n\n#### Morning\n- **7:00 AM - Visit the Taj Mahal**\n  - **Duration:** 2 hours\n  - **Details:** Start your day early to witness the sunrise at the Taj Mahal, a UNESCO World Heritage Site and one of the Seven Wonders of the World.\n  - **Cost:** INR 1,300 (foreigners) / INR 50 (Indians)\n  \n- **9:00 AM - Breakfast at Joney’s Place**\n  - **Duration:** 1 hour\n  - **Details:** Enjoy a hearty breakfast at this popular local spot known for its delicious Indian breakfast options.\n  - **Cost:** INR 200\n\n#### Late Morning\n- **10:30 AM - Visit Agra Fort**\n  - **Duration:** 2 hours\n  - **Details:** Explore this massive red sandstone fort, another UNESCO World Heritage Site, featuring impressive gates and stunning views of the Taj Mahal.\n  - **Cost:** INR 650 (foreigners) / INR 50 (Indians)\n\n#### Afternoon\n- **1:00 PM - Lunch at Pinch of Spice**\n  - **Duration:** 1 hour\n  - **Details:** Savor authentic Mughlai cuisine, including kebabs and biryanis, at this well-reviewed restaurant.\n  - **Cost:** INR 700\n\n- **2:30 PM - Visit Itimad-ud-Daulah (Baby Taj)**\n  - **Duration:** 1.5 hours\n  - **Details:** Known for its intricate marble inlay work, this mausoleum is often referred to as the 'Baby Taj.'\n  - **Cost:** INR 300\n\n#### Evening\n- **4:00 PM - Stroll through Kinari Bazaar**\n  - **Duration:** 1.5 hours\n  - **Details:** Explore this vibrant market known for its handicrafts, marble souvenirs, and textiles.\n  - **Cost:** Free\n\n- **6:00 PM - Visit Mehtab Bagh**\n  - **Duration:** 1.5 hours\n  - **Details:** Relax in this garden complex across the Yamuna River, offering stunning sunset views of the Taj Mahal.\n  - **Cost:** INR 200\n\n- **7:30 PM - Dinner at Esphahan, Oberoi Amarvilas**\n  - **Duration:** 2 hours\n  - **Details:** Experience fine dining with views of the Taj Mahal, serving contemporary Indian cuisine.\n  - **Cost:** INR 2,500+\n\n### Day 2: Cultural Immersion and Culinary Delights\n\n#### Morning\n- **7:30 AM - Breakfast at the Hotel**\n  - **Duration:** 1 hour\n  - **Details:** Enjoy a leisurely breakfast at your hotel.\n\n- **8:30 AM - Excursion to Fatehpur Sikri**\n  - **Duration:** 3 hours\n  - **Details:** Drive to this UNESCO World Heritage Site, the former capital of Emperor Akbar, featuring impressive palaces and the grand Buland Darwaza.\n  - **Cost:** INR 610 (foreigners) / INR 50 (Indians)\n\n#### Afternoon\n- **12:00 PM - Return to Agra and Lunch at Dasaprakash**\n  ...
# ================================== Ai Message ==================================
#
# Here's a detailed 2-day itinerary for Agra, tailored for a history and culture lover, including special cuisine experiences.
#
# ### Day 1: Exploring Agra's Heritage
#
# #### Morning
# - **7:00 AM - Visit the Taj Mahal**
#   - **Duration:** 2 hours
#   - **Details:** Start your day early to witness the sunrise at the Taj Mahal, a UNESCO World Heritage Site and one of the Seven Wonders of the World.
#   - **Cost:** INR 1,300 (foreigners) / INR 50 (Indians)
#
# - **9:00 AM - Breakfast at Joney’s Place**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy a hearty breakfast at this popular local spot known for its delicious Indian breakfast options.
#   - **Cost:** INR 200
#
# #### Late Morning
# - **10:30 AM - Visit Agra Fort**
#   - **Duration:** 2 hours
#   - **Details:** Explore this massive red sandstone fort, another UNESCO World Heritage Site, featuring impressive gates and stunning views of the Taj Mahal.
#   - **Cost:** INR 650 (foreigners) / INR 50 (Indians)
#
# #### Afternoon
# - **1:00 PM - Lunch at Pinch of Spice**
#   - **Duration:** 1 hour
#   - **Details:** Savor authentic Mughlai cuisine, including kebabs and biryanis, at this well-reviewed restaurant.
#   - **Cost:** INR 700
#
# - **2:30 PM - Visit Itimad-ud-Daulah (Baby Taj)**
#   - **Duration:** 1.5 hours
#   - **Details:** Known for its intricate marble inlay work, this mausoleum is often referred to as the 'Baby Taj.'
#   - **Cost:** INR 300
#
# #### Evening
# - **4:00 PM - Stroll through Kinari Bazaar**
#   - **Duration:** 1.5 hours
#   - **Details:** Explore this vibrant market known for its handicrafts, marble souvenirs, and textiles.
#   - **Cost:** Free
#
# - **6:00 PM - Visit Mehtab Bagh**
#   - **Duration:** 1.5 hours
#   - **Details:** Relax in this garden complex across the Yamuna River, offering stunning sunset views of the Taj Mahal.
#   - **Cost:** INR 200
#
# - **7:30 PM - Dinner at Esphahan, Oberoi Amarvilas**
#   - **Duration:** 2 hours
#   - **Details:** Experience fine dining with views of the Taj Mahal, serving contemporary Indian cuisine.
#   - **Cost:** INR 2,500+
#
# ### Day 2: Cultural Immersion and Culinary Delights
#
# #### Morning
# - **7:30 AM - Breakfast at the Hotel**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy a leisurely breakfast at your hotel.
#
# - **8:30 AM - Excursion to Fatehpur Sikri**
#   - **Duration:** 3 hours
#   - **Details:** Drive to this UNESCO World Heritage Site, the former capital of Emperor Akbar, featuring impressive palaces and the grand Buland Darwaza.
#   - **Cost:** INR 610 (foreigners) / INR 50 (Indians)
#
# #### Afternoon
# - **12:00 PM - Return to Agra and Lunch at Dasaprakash**
#   - **Duration:** 1 hour
#   - **Details:** Enjoy delicious South Indian vegetarian cuisine, famous for dosas and thalis.
#   - **Cost:** INR 500
#
# - **1:30 PM - Visit Akbar's Tomb in Sikandra**
#   - **Duration:** 1.5 hours
#   - **Details:** Explore this architectural marvel set amidst beautiful gardens, reflecting the grandeur of the Mughal Empire.
#   - **Cost:** INR 100
#
# #### Evening
# - **3:00 PM - Relax at the Hotel**
#   - **Duration:** 1.5 hours
#   - **Details:** Take some time to rest and refresh before the evening activities.
#
# - **5:00 PM - Mughal Heritage Walk**
#   - **Duration:** 2 hours
#   - **Details:** Participate in a guided tour through the lesser-known parts of Agra, offering insights into local lifestyle and history.
#   - **Cost:** INR 1,000 (approx.)
#
# - **7:30 PM - Dinner at Peshawri, ITC Mughal**
#   - **Duration:** 2 hours
#   - **Details:** Dine on exquisite North-West Frontier cuisine in a luxurious setting, perfect for concluding your cultural journey.
#   - **Cost:** INR 2,000
#
# ### Practical Tips
# - **Transportation:** Auto-rickshaws are available for short distances; consider hiring a private car for longer trips.
# - **Best Time to Visit:** October to March for pleasant weather.
# - **Must-Try Food:** Bedai-Jalebi, Mughlai Biryani, Petha (a local sweet).
# - **Shopping:** Sadar Bazaar for handicrafts, Kinari Bazaar for marble souvenirs.
#
# Enjoy your enriching journey through Agra's history, culture, and cuisine!

# %% [markdown]
# # **Step 4 - Design Your Agent State**

# %% [markdown]
# ## Graph State

# %%
from typing import TypedDict, Annotated, List, Optional
import operator
from langchain.messages import AnyMessage

# %%
class AgentTask(BaseModel):
    """A single agent task with targeted query."""
    source: Literal["search_agent_node", "planner_agent_node"]
    user_query: str
    focus: str = ""  # What aspect this agent should focus on

# %%
##### Main Graph State ######

class TravelPlannerState(TypedDict):
    """Enhanced state for parallel execution."""

    # Conversation history
    messages: Annotated[List[AnyMessage], operator.add]

    # Current user query
    user_query: str

    # Tasks from router (replaces single classification)
    tasks: List[AgentTask]

    # Flag for synthesis
    requires_synthesis: bool

    # Parallel agent results - KEY: uses operator.add for concurrent writes
    agent_results: Annotated[List[dict], operator.add]

    # Final synthesized answer
    final_answer: str

    search_messages: Annotated[List[AnyMessage], operator.add]
    planner_messages: Annotated[List[AnyMessage], operator.add]

# %% [markdown]
# # **Step 5 - Build Your Nodes**

# %% [markdown]
# ## Orchestrator
#
#
# *  Breaks down tasks into subtasks
# *  Delegates subtasks to workers/nodes
#
#
# *   Synthesizes worker outputs into a final result
#
# ![image.png](data:image/png;base64,...)

# %%
from langgraph.types import Send
from langchain.messages import SystemMessage, ToolMessage, HumanMessage, AIMessage

# %%
class ClassificationResult(BaseModel):
    """Router output - now supports MULTIPLE parallel tasks."""
    tasks: List[AgentTask] = Field(
        description="List of agents to invoke with their targeted queries"
    )
    requires_synthesis: bool = Field(
        default=False,
        description="Whether multiple agents are being used and synthesis is needed"
    )

# %%
# Worker/Node state for individual agents
class AgentWorkerState(TypedDict):
    """State passed to each parallel worker."""
    task: AgentTask
    messages: List[AnyMessage]
    agent_results: Annotated[List[dict], operator.add]

# %%
def classify_query_parallel(state: TravelPlannerState) -> dict:
    """
    Updated router that can dispatch to MULTIPLE agents.
    """
    router_llm = llm
    structured_llm = router_llm.with_structured_output(ClassificationResult)

    result = structured_llm.invoke([
        {
            "role": "system",
            "content": """ You are a Travel Request Router that can dispatch to MULTIPLE agents in parallel.

AVAILABLE AGENTS:
1. search_agent_node - Flight searches, hotel searches, pricing, availability
2. planner_agent_node - Itineraries, travel tips, weather, visas, activities, general guidance

ROUTING RULES:

SINGLE AGENT (requires_synthesis = false):
- Flight/hotel ONLY → search_agent_node
- Itinerary/planning ONLY → planner_agent_node
- General travel questions → planner_agent_node

MULTIPLE AGENTS (requires_synthesis = true):
- "Plan a trip AND find flights/hotels" → BOTH agents
- "Find hotels and create itinerary" → BOTH agents
- Requests mentioning BOTH booking AND planning → BOTH agents

When dispatching to BOTH agents:
1. Create a focused sub-query for each agent
2. search_agent_node query should focus on flights/hotels/pricing
3. planner_agent_node query should focus on itinerary/activities/tips

EXAMPLES:

Query: "Find flights from DEL to DXB"
→ tasks: [{"source": "search_agent_node", "user_query": "Find flights from DEL to DXB"}]
→ requires_synthesis: false

Query: "Plan a 5-day trip to Paris"
→ tasks: [{"source": "planner_agent_node", "user_query": "Plan a 5-day trip to Paris"}]
→ requires_synthesis: false

Query: "Plan a week in London and find me hotels under $200/night"
→ tasks: [
    {"source": "search_agent_node", "user_query": "Find hotels in London under $200/night for 1 week", "focus": "hotel search and pricing"},
    {"source": "planner_agent_node", "user_query": "Plan a week-long itinerary for London", "focus": "daily activities and attractions"}
  ]
→ requires_synthesis: true

Query: "I want to visit Tokyo - book flights from NYC and create a 5-day itinerary"
→ tasks: [
    {"source": "search_agent_node", "user_query": "Find flights from NYC to Tokyo", "focus": "flight options and prices"},
    {"source": "planner_agent_node", "user_query": "Create a 5-day itinerary for Tokyo", "focus": "daily schedule and activities"}
  ]
→ requires_synthesis: true """
        },
        {"role": "user", "content": state["user_query"]}
    ])

    return {
        "tasks": result.tasks,
        "requires_synthesis": result.requires_synthesis
    }

# %%
def dispatch_to_agents(state: TravelPlannerState):
    """
    Uses Send API to dispatch tasks to agents in PARALLEL.
    This is the key function that enables concurrent execution.
    """
    tasks = state.get("tasks", [])

    sends = []
    for task in tasks:

        # Construct the worker_state, ensuring agent-specific message histories
        # and agent_results are carried forward, not reset.
        worker_state = {
              "messages": state.get("messages", []),
              "user_query": task.user_query,
              "tasks": state.get("tasks", []),
              "requires_synthesis": state.get("requires_synthesis", False),
              "final_answer": state.get("final_answer", ""), # Carry forward if exists
              "search_messages": state.get("search_messages", []), # Carry forward existing history
              "planner_messages": state.get("planner_messages", []), # Carry forward existing history
              "agent_results": state.get("agent_results", []), # Carry forward existing results
        }

        if task.source == "search_agent_node":
            sends.append(Send("search_agent_node", worker_state))
        elif task.source == "planner_agent_node":
            sends.append(Send("planner_agent_node", worker_state))

    return sends

# %% [markdown]
# ### Synthesizer

# %%
def synthesizer_node(state: TravelPlannerState) -> dict:
    """
    Combines results from parallel agents into a unified response.
    Only called when requires_synthesis is True.
    """

    agent_results = state.get("agent_results", [])

    if not agent_results:
        return {
            "final_answer": "I couldn't process your request.",
            "messages": [AIMessage(content="I couldn't process your request.")]
        }

    # If only one result, no synthesis needed
    if len(agent_results) == 1:
        result = agent_results[0]["result"]
        return {
            "final_answer": result,
            "messages": [AIMessage(content=result)]
        }

    # Format results for synthesis
    results_formatted = "\n\n" + "="*50 + "\n\n".join([
        f"**{r['agent'].upper()}**\nFocus: {r.get('focus', 'N/A')}\n\n{r['result']}"
        for r in agent_results
    ])

    synthesis_prompt = """You are a Travel Response Synthesizer. Combine multiple agent outputs into
a single, well-organized, comprehensive response.

RULES:
1. Organize logically (e.g., Flights → Hotels → Itinerary → Tips)
2. Don't repeat information
3. Highlight key recommendations
4. Note any conflicts or alternatives
5. Create clear sections with headers
6. End with actionable next steps

Original Query: {query}

Agent Results:
{results}

Create a unified, helpful response:"""

    response = llm.invoke([
        HumanMessage(content=synthesis_prompt.format(
            query=state["user_query"],
            results=results_formatted
        ))
    ])

    return {
        "final_answer": response.content,
        "messages": [AIMessage(content=response.content)]
    }

# %% [markdown]
# ## Define Search (Flight & Hotel) and Planner (TravelScout & ItineraryResearch) Nodes

# %% [markdown]
# ### Augment the LLM with tools

# %%
# Augment the LLM with tools

search_tools_by_name = {tool.name: tool for tool in search_tools}
search_model_with_tools = llm.bind_tools(search_tools)

# %%
planner_tools = [internet_search, call_itinerary_research_agent]
planner_model_with_tools = llm.bind_tools(planner_tools)

# %% [markdown]
# ### Search Agent & Tool Node

# %%
def search_agent_node(state: TravelPlannerState):
    """Search agent with its own message history"""

    search_msgs = state.get("search_messages", [])

    # Start with the system prompt
    current_conversation_history = [SystemMessage(content=flightHotelSearch_instructions)]

    # If this is the very first message for this agent (meaning search_msgs is empty),
    # append the user query. Otherwise, extend with existing agent-specific messages.
    if not search_msgs:
        # The user query for this specific task will be in the 'user_query' field
        current_conversation_history.append(HumanMessage(content=state.get("user_query", "")))
    else:
        current_conversation_history.extend(search_msgs)

    response = search_model_with_tools.invoke(current_conversation_history)

    # Append the new AI message to the agent's specific message history
    updated_search_messages = search_msgs + [response]

    # Decide if this is a final answer for agent_results
    agent_result_entry = []
    if not response.tool_calls:
        # This is a final answer from the search agent, so add its result
        agent_result_entry = [{
            "agent": "search_agent",
            "focus": "flights and hotels",
            "result": response.content
        }]

    return {
        "search_messages": updated_search_messages,
        "agent_results": agent_result_entry
    }

# %%
def search_tool_node(state: TravelPlannerState):
    """Execute search tools"""
    search_msgs = state.get("search_messages", [])

    # This node should only be reached if there are tool calls to execute
    if not search_msgs or not (hasattr(search_msgs[-1], 'tool_calls') and search_msgs[-1].tool_calls):
        return {"search_messages": []} # Should not happen if routed correctly

    last_message = search_msgs[-1]

    result_tool_messages = []
    for tool_call in last_message.tool_calls:
        tool = search_tools_by_name.get(tool_call['name'])
        if tool:
            observation = tool.invoke(tool_call['args'])
            result_tool_messages.append(ToolMessage(content=observation, tool_call_id=tool_call['id']))

    # Append the tool messages to the existing history
    return {"search_messages": search_msgs + result_tool_messages}

# %% [markdown]
# ### Planner Agent & Tool Node

# %%
def planner_agent_node(state: TravelPlannerState):
    """Planner agent with its own message history"""

    planner_msgs = state.get("planner_messages", [])

    # Start with the system prompt
    current_conversation_history = [SystemMessage(content=travel_scout_instructions)]

    # If this is the very first message for this agent (meaning planner_msgs is empty),
    # append the user query. Otherwise, extend with existing agent-specific messages.
    if not planner_msgs:
        # The user query for this specific task will be in the 'user_query' field
        current_conversation_history.append(HumanMessage(content=state.get("user_query", "")))
    else:
        current_conversation_history.extend(planner_msgs)

    response = planner_model_with_tools.invoke(current_conversation_history)

    # Append the new AI message to the agent's specific message history
    updated_planner_messages = planner_msgs + [response]

    # Decide if this is a final answer for agent_results
    agent_result_entry = []
    if not response.tool_calls:
        # This is a final answer from the planner agent, so add its result
        agent_result_entry = [{
            "agent": "planner_agent",
            "focus": "travel planning and itinerary",
            "result": response.content
        }]

    return {
        "planner_messages": updated_planner_messages,
        "agent_results": agent_result_entry
    }

# %%
def planner_tool_node(state: TravelPlannerState):
    """Execute planner tools"""
    planner_msgs = state.get("planner_messages", [])

    # This node should only be reached if there are tool calls to execute
    if not planner_msgs or not (hasattr(planner_msgs[-1], 'tool_calls') and planner_msgs[-1].tool_calls):
        return {"planner_messages": []} # Should not happen if routed correctly

    last_message = planner_msgs[-1]

    planner_tools_by_name = {tool.name: tool for tool in planner_tools}
    result_tool_messages = []

    for tool_call in last_message.tool_calls:
        tool = planner_tools_by_name.get(tool_call['name'])
        if tool:
            observation = tool.invoke(tool_call['args'])
            result_tool_messages.append(ToolMessage(content=observation, tool_call_id=tool_call['id']))

    # Append the tool messages to the existing history
    return {"planner_messages": planner_msgs + result_tool_messages}

# %% [markdown]
# ### Conditional Edges

# %%
def should_continue_for_searchAgent(state: TravelPlannerState):
    search_msgs = state.get("search_messages", [])
    if search_msgs and hasattr(search_msgs[-1], 'tool_calls') and search_msgs[-1].tool_calls:
        return "search_tool_node"
    return "synthesizer"

# %%
def should_continue_for_plannerAgent(state: TravelPlannerState):
    """Check if planner needs to continue tool loop"""
    planner_msgs = state.get("planner_messages", [])
    if planner_msgs and hasattr(planner_msgs[-1], 'tool_calls') and planner_msgs[-1].tool_calls:
        return "planner_tool_node"
    return "synthesizer"

# %% [markdown]
# # **Step 6 - Build & Compile Your Workflow**

# %%
from typing import Literal
from langgraph.graph import StateGraph, START, END

# %%
def build_parallel_travel_agent():
    """Build the graph with parallel execution support."""

    builder = StateGraph(TravelPlannerState)

    # Add nodes
    builder.add_node("orchestrator", classify_query_parallel)
    builder.add_node("search_agent_node", search_agent_node)
    builder.add_node("planner_agent_node", planner_agent_node)
    builder.add_node("search_tool_node", search_tool_node)
    builder.add_node("planner_tool_node", planner_tool_node)
    builder.add_node("synthesizer", synthesizer_node)

    # Connect edges
    builder.add_edge(START, "orchestrator")

    # Router dispatches to agents via Send API (parallel execution)
    builder.add_conditional_edges(
        "orchestrator",
        dispatch_to_agents,
        ["search_agent_node", "planner_agent_node"]
    )

    # Search agent tool loop
    builder.add_conditional_edges(
        "search_agent_node",
        should_continue_for_searchAgent,
        ["search_tool_node", "synthesizer"]  # Go to synthesizer instead of END
    )
    builder.add_edge("search_tool_node", "search_agent_node")

    # Planner agent tool loop
    builder.add_conditional_edges(
        "planner_agent_node",
        should_continue_for_plannerAgent,
        ["planner_tool_node", "synthesizer"]  # Go to synthesizer instead of END
    )
    builder.add_edge("planner_tool_node", "planner_agent_node")

    # End after synthesis
    builder.add_edge("synthesizer", END)

    return builder.compile()

# %%
# Compile the agent
agent = build_parallel_travel_agent()

# %%
# Show the agent
from IPython.display import Image, display
display(Image(agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# # **Step 7 - Test the Multi-Agent System**

# %% [markdown]
# ### Test Multi-Agent Travel Planner

# %%
"""
result = agent.invoke({
        "user_query": "Plan a 5-day trip to Paris and find me flights from JFK to LHR for 1 adult only on 21 Jan 2026 (one way trip) & also let me know hotels for myself only (adult) from my lading to LHR to next day",
        "messages": [],
        "tasks": [],
        "requires_synthesis": False,
        "agent_results": [],
        "final_answer": "",
        "search_messages": [],
        "planner_messages": [],
    },
    config=config
)

# Print everything step by step
print("=" * 60)
print("USER QUERY:")
print(result["user_query"])

print("\n" + "=" * 60)
print("TASKS DISPATCHED:")
for task in result.get("tasks", []):
    print(f"  • {task.source}: {task.user_query}")

print("\n" + "=" * 60)
print("AGENT RESULTS:")
for r in result.get("agent_results", []):
    print(f"\n[{r['agent'].upper()}]")
    print("-" * 40)
    print(r["result"][:50000] + "..." if len(r["result"]) > 500 else r["result"])

print("\n" + "=" * 60)
print("FINAL SYNTHESIZED RESPONSE:")
print("=" * 60)
print(result["final_answer"])
"""
# Out:
# '\nresult = agent.invoke({\n        "user_query": "Plan a 5-day trip to Paris and find me flights from JFK to LHR for 1 adult only on 21 Jan 2026 (one way trip) & also let me know hotels for myself only (adult) from my lading to LHR to next day",\n        "messages": [],\n        "tasks": [],\n        "requires_synthesis": False,\n        "agent_results": [],\n        "final_answer": "",\n        "search_messages": [],\n        "planner_messages": [],\n    },\n    config=config\n)\n\n# Print everything step by step\nprint("=" * 60)\nprint("USER QUERY:")\nprint(result["user_query"])\n\nprint("\n" + "=" * 60)\nprint("TASKS DISPATCHED:")\nfor task in result.get("tasks", []):\n    print(f"  • {task.source}: {task.user_query}")\n\nprint("\n" + "=" * 60)\nprint("AGENT RESULTS:")\nfor r in result.get("agent_results", []):\n    print(f"\n[{r[\'agent\'].upper()}]")\n    print("-" * 40)\n    print(r["result"][:50000] + "..." if len(r["result"]) > 500 else r["result"])\n\nprint("\n" + "=" * 60)\nprint("FINAL SYNTHESIZED RESPONSE:")\nprint("=" * 60)\nprint(result["final_answer"])\n'

# %%
"""
# Print everything step by step
print("=" * 60)
print("USER QUERY:")
print(result["user_query"])

print("\n" + "=" * 60)
print("TASKS DISPATCHED:")
for task in result.get("tasks", []):
    print(f"  • {task.source}: {task.user_query}")

print("\n" + "=" * 60)
print("AGENT RESULTS:")
for r in result.get("agent_results", []):
    print(f"\n[{r['agent'].upper()}]")
    print("-" * 40)
    print(r["result"][:50000] + "..." if len(r["result"]) > 500 else r["result"])

print("\n" + "=" * 60)
print("FINAL SYNTHESIZED RESPONSE:")
print("=" * 60)
print(result["final_answer"])
"""
# Out:
# '\n# Print everything step by step\nprint("=" * 60)\nprint("USER QUERY:")\nprint(result["user_query"])\n\nprint("\n" + "=" * 60)\nprint("TASKS DISPATCHED:")\nfor task in result.get("tasks", []):\n    print(f"  • {task.source}: {task.user_query}")\n\nprint("\n" + "=" * 60)\nprint("AGENT RESULTS:")\nfor r in result.get("agent_results", []):\n    print(f"\n[{r[\'agent\'].upper()}]")\n    print("-" * 40)\n    print(r["result"][:50000] + "..." if len(r["result"]) > 500 else r["result"])\n\nprint("\n" + "=" * 60)\nprint("FINAL SYNTHESIZED RESPONSE:")\nprint("=" * 60)\nprint(result["final_answer"])\n'

# %% [markdown]
# # **Add Persistence**

# %%
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.runnables import RunnableConfig

# %%
def build_parallel_travel_agent():
    """Build the graph with parallel execution support."""

    builder = StateGraph(TravelPlannerState)

    # Add nodes
    builder.add_node("orchestrator", classify_query_parallel)
    builder.add_node("search_agent_node", search_agent_node)
    builder.add_node("planner_agent_node", planner_agent_node)
    builder.add_node("search_tool_node", search_tool_node)
    builder.add_node("planner_tool_node", planner_tool_node)
    builder.add_node("synthesizer", synthesizer_node)

    # Connect edges
    builder.add_edge(START, "orchestrator")

    # Router dispatches to agents via Send API (parallel execution)
    builder.add_conditional_edges(
        "orchestrator",
        dispatch_to_agents,
        ["search_agent_node", "planner_agent_node"]
    )

    # Search agent tool loop
    builder.add_conditional_edges(
        "search_agent_node",
        should_continue_for_searchAgent,
        ["search_tool_node", "synthesizer"]  # Go to synthesizer instead of END
    )
    builder.add_edge("search_tool_node", "search_agent_node")

    # Planner agent tool loop
    builder.add_conditional_edges(
        "planner_agent_node",
        should_continue_for_plannerAgent,
        ["planner_tool_node", "synthesizer"]  # Go to synthesizer instead of END
    )
    builder.add_edge("planner_tool_node", "planner_agent_node")

    # End after synthesis
    builder.add_edge("synthesizer", END)

    # Built-in Persistence
    checkpointer = InMemorySaver()

    return builder.compile(checkpointer=checkpointer)

# %%
# Compile the agent
agent = build_parallel_travel_agent()

# %%
config = {"configurable": {"thread_id": "user-01"}}

# %%
result = agent.invoke(
    {
        "user_query": "What is the best time to visit Jaipur?",
        "messages": [],
        "tasks": [],
        "requires_synthesis": False,
        "agent_results": [],
        "final_answer": "",
        "search_messages": [],
        "planner_messages": [],
    },
    config=config
)

print(result['final_answer'])
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_40062/77278029.py in <cell line: 0>()
# ----> 1 result = agent.invoke(
#       2     {
#       3         "user_query": "What is the best time to visit Jaipur?",
#       4         "messages": [],
#       5         "tasks": [],
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3911         else:
#    3912             # v1: collect interrupts from updates stream
# -> 3913             for chunk in self.stream(
#    3914                 input,
#    3915                 config,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965                     for task in loop.match_cached_writes():
#    2966                         loop.output_writes(task.id, task.writes, cached=True)
# -> 2967                     for _ in runner.tick(
#    2968                         [t for t in loop.tasks.values() if not t.writes],
#    2969                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205             scheduled_error_handler = False
#     206             try:
# --> 207                 run_with_retry(
#     208                     t,
#     209                     retry_policy,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_retry.py in run_with_retry(task, retry_policy, configurable)
#     615             task.writes.clear()
#     616             # run the task
# --> 617             return task.proc.invoke(task.input, config)
#     618         except ParentCommand as exc:
#     619             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     682                     # run in context
#     683                     with set_config_context(config, run) as context:
# --> 684                         input = context.run(step.invoke, input, config, **kwargs)
#     685                 else:
#     686                     input = step.invoke(input, config)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     424                 run_manager.on_chain_end(ret)
#     425         else:
# --> 426             ret = self.func(*args, **kwargs)
#     427         if self.recurse and isinstance(ret, Runnable):
#     428             return ret.invoke(input, config)
#
# /tmp/ipykernel_40062/1951276.py in planner_agent_node(state)
#      15         current_conversation_history.extend(planner_msgs)
#      16
# ---> 17     response = planner_model_with_tools.invoke(current_conversation_history)
#      18
#      19     # Append the new AI message to the agent's specific message history
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    6000         **kwargs: Any | None,
#    6001     ) -> Output:
# -> 6002         return self.bound.invoke(
#    6003             input,
#    6004             self._merge_configs(config),
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     474             cast(
#     475                 "ChatGeneration",
# --> 476                 self.generate_prompt(
#     477                     [self._convert_input(input)],
#     478                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1847     ) -> LLMResult:
#    1848         prompt_messages = [p.to_messages() for p in prompts]
# -> 1849         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1850
#    1851     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1654             try:
#    1655                 results.append(
# -> 1656                     self._generate_with_cache(
#    1657                         m,
#    1658                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992             result = generate_from_stream(iter(chunks))
#    1993         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994             result = self._generate(
#    1995                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1996             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#    1743                 response = raw_response.parse()
#    1744         except openai.BadRequestError as e:
# -> 1745             _handle_openai_bad_request(e)
#    1746         except openai.APIError as e:
#    1747             _handle_openai_api_error(e)
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#    1740                 )
#    1741             else:
# -> 1742                 raw_response = self.client.with_raw_response.create(**payload)
#    1743                 response = raw_response.parse()
#    1744         except openai.BadRequestError as e:
#
# /usr/local/lib/python3.12/dist-packages/openai/_legacy_response.py in wrapped(*args, **kwargs)
#     365         kwargs["extra_headers"] = extra_headers
#     366
# --> 367         return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#     368
#     369     return wrapped
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     296                         msg = f"Missing required argument: {quote(missing[0])}"
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#     300         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1279     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280         validate_response_format(response_format)
# -> 1281         return self._post(
#    1282             "/chat/completions",
#    1283             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1330             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331         )
# -> 1332         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1333
#    1334     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1103
#    1104                 log.debug("Re-raising status error")
# -> 1105                 raise self._make_status_error_from_response(err.response) from None
#    1106
#    1107             break
#
# BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_VkWyers2YdNMxjLhLuSQ6081", 'type': 'invalid_request_error', 'param': 'messages.[2].role', 'code': None}}

# %%
result = agent.invoke(
    {
        "user_query": "Major historical sites there (must visit kind of)",
        "messages": [],
        "tasks": [],
        "requires_synthesis": False,
        "agent_results": [],
        "final_answer": "",
        "search_messages": [],
        "planner_messages": [],
    },
    config=config
)

print(result['final_answer'])

# %%
result = agent.invoke(
    {
        "user_query": "What all cities I can cover along with this tour (in nearby which should not take more than 2-3 days extra)",
        "messages": [],
        "tasks": [],
        "requires_synthesis": False,
        "agent_results": [],
        "final_answer": "",
        "search_messages": [],
        "planner_messages": [],
    },
    config=config
)

print(result['final_answer'])
